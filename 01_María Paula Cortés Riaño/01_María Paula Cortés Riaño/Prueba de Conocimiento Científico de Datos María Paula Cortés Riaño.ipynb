# %% [markdown]
# **Librerías a usar**

# %%
from google.colab import drive

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

import csv
from math import radians, sin, cos, sqrt, atan2
import json

from tqdm import tqdm
tqdm.pandas()

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import ElasticNet
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_percentage_error

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir(os.getcwd())

# %% [markdown]
# **Cargue de insumos**

# %%
puntos_interes = pd.read_csv('PuntosInteres.csv', dtype=str, encoding='latin1', header=None, delimiter=';', low_memory=False)
puntos_interes.columns = ['longitud', 'latitud', 'categoria', 'nombre']

puntos_interes.head()
# Out:
#       longitud     latitud categoria                        nombre
# 0  -73.9224858   4.5294102  pharmacy                    No hallado
# 1  -75.5560536  10.3961543  pharmacy                    No hallado
# 2  -75.5610232  10.3942042  pharmacy                    No hallado
# 3  -74.2064019   4.7153596  pharmacy  DroguerÐa Colsubsidio Funza
# 4    -75.57863   6.1842195  pharmacy              Farmacia Pasteur

# %%
train_data = pd.read_csv('train_precios_vivienda.csv', dtype=str, index_col=0, low_memory=False)
test_data = pd.read_csv('test_precios_vivienda.csv', delimiter=';', low_memory=False)

# %% [markdown]
# **Limpieza y preparación de datos**

# %%
# Se inicia por eliminar de ambos dataset las columnas que son descriptivas y aquellas relacionadas con registros inmobiliarios y catastrales que se considera no tienen incidencia en la estimación del valor total del avaluo
columnas_a_eliminar = ['direccion_inmueble_informe', 'descripcion_general_sector', 'perspectivas_de_valorizacion', 'actualidad_edificadora','comportamiento_oferta_demanda', 'descripcion_tipo_inmueble', 'descripcion_uso_inmueble',
'descripcion_clase_inmueble', 'observaciones_altura_permitida','observaciones_aislamiento_posterior', 'observaciones_aislamiento_lateral', 'observaciones_antejardin', 'observaciones_indice_ocupacion',
'observaciones_indice_construccion', 'observaciones_generales_inmueble', 'condicion_ph', 'observaciones_estructura', 'observaciones_dependencias', 'numero_garaje_1', 'numero_garaje_2', 'numero_garaje_3',
'numero_garaje_4', 'numero_garaje_5', 'matricula_garaje_1', 'matricula_garaje_2', 'matricula_garaje_3', 'matricula_garaje_4', 'matricula_garaje_5', 'numero_deposito_1', 'matricula_inmobiliaria_deposito_1',
'numero_deposito_2', 'matricula_inmobiliaria_deposito_2', 'numero_deposito_3', 'matricula_inmobiliaria_deposito_3', 'numero_deposito_4', 'matricula_inmobiliaria_deposito_4', 'numero_deposito_5','uso_principal_ph',
'matricula_inmobiliaria_deposito_5', 'observaciones_generales_construccion', 'metodo_valuacion_1', 'metodo_valuacion_1', 'concepto_del_metodo_1', 'metodo_valuacion_2','concepto_del_metodo_2','metodo_valuacion_3',
'concepto_del_metodo_3','metodo_valuacion_4','concepto_del_metodo_4','metodo_valuacion_5', 'concepto_del_metodo_5', 'metodo_valuacion_6', 'concepto_del_metodo_6', 'metodo_valuacion_7', 'concepto_del_metodo_7',
'metodo_valuacion_8', 'concepto_del_metodo_8','metodo_valuacion_9', 'concepto_del_metodo_9', 'barrio', 'unidades', 'garaje_paralelo_4', 'garaje_doble_5', 'garaje_paralelo_5', 'garaje_servidumbre_5', 'fecha_aprobación', 'valor_uvr', 'valor_avaluo_en_uvr',
'ocupante','altura_permitida','aislamiento_lateral','aislamiento_posterior','indice_construccion','detalle_material','uso_principal_ph','area_actividad','indice_ocupacion']

for columna in columnas_a_eliminar:
    if columna in train_data.columns:
        train_data.drop(columna, axis=1, inplace=True)
    if columna in test_data.columns:
        test_data.drop(columna, axis=1, inplace=True)

# %%
# En segundo lugar, se hace limpieza de acentos en ambos dataset
diccionario_acentos = {
    'Ã¡': 'á',
    'Ã©': 'é',
    'Ã­': 'í',
    'Ã\xad': 'í',
    'Ã³': 'ó',
    'Ãº': 'ú',
    'Ã¼': 'ü',
    'Ã\x81': 'Á',
    'Ã‰': 'É',
    'Ã\x8d': 'Í',
    'Ã“': 'Ó',
    'Ãš': 'Ú',
    'Ãœ': 'Ü',
    'Ã±': 'ñ',
    'Ã‘':'Ñ'}
train_data.replace(diccionario_acentos, regex=True, inplace=True)
test_data.replace(diccionario_acentos, regex=True, inplace=True)

# %%
# En tercer lugar, para las columnas restantes que son de tipo de texto, se depura aquello que no corresponda a los datos esperados en la columna.

# Para esto, se empieza por unir temporalmente los dataframe en sus columnas comunes a fin de hacer una única revisión de los valores posibles en cada columna
df_concatenado = pd.concat([train_data, test_data], ignore_index=True)

valores_unicos_por_columna = {}

for columna in df_concatenado.columns:
    valores_unicos_por_columna[columna] = df_concatenado[columna].unique()

# Imprimir los valores únicos por columna
for columna, valores_unicos in valores_unicos_por_columna.items():
    print(f'Valores únicos en la columna "{columna}":')
    print(valores_unicos)
    print('\n')
# Out:
# Valores únicos en la columna "id":
# ['5896' '10570' '14600' ... 8095 7435 16318]
#
#
# Valores únicos en la columna "objeto":
# ['Remate' 'Originación' '2018-06-19 19:48:27.269-05']
#
#
# Valores únicos en la columna "motivo":
# ['Remates' 'Crédito hipotecario de vivienda' 'Colomext Hipotecario'
#  'Empleados' 'Leasing Habitacional' 'Garantía' 'Compra de cartera'
#  'Crédito Comercial' 'Actualización de garantías' 'Dación en Pago'
#  'Hipotecario Visto Bueno' 'Leasing Visto Bueno'
#  'Leasing Inmobiliario - Persona Natural' '0' 'Leasing Comercial'
#  'Originación' 'Reformas']
#
#
# Valores únicos en la columna "proposito":
# ['Garantía Hipotecaria' 'Valor Asegurable'
#  'Transacción Comercial de Venta' '0' 'Crédito hipotecario de vivienda']
#
#
# Valores únicos en la columna "tipo_avaluo":
# ['Remates' 'Hipotecario' 'Garantía Hipotecaria']
#
#
# Valores únicos en la columna "tipo_credito":
# ['Vivienda' 'Diferente de Vivienda' '0' 'Hipotecario']
#
#
# Valores únicos en la columna "tipo_subsidio":
# [nan 'VIS' 'Frech II' 'VIP' 'Gratuita' 'Vivienda']
#
#
# Valores únicos en la columna "departamento_inmueble":
# ['VALLE DEL CAUCA' 'QUINDÍO' 'ANTIOQUIA' 'CUNDINAMARCA' 'META'
#  'BOGOTÁ, D. C.' 'SANTANDER' 'CÓRDOBA' 'NARIÑO' 'GUAVIARE' 'CALDAS'
#  'BOLÍVAR' 'ATLÁNTICO' 'TOLIMA' 'RISARALDA' 'CESAR' 'CASANARE' 'MAGDALENA'
#  'NORTE DE SANTANDER' 'HUILA' 'PUTUMAYO' 'CAUCA' 'BOYACÁ' 'SUCRE'
#  'LA GUAJIRA' 'AMAZONAS' 'CAQUETÁ' 'Ochoa Vahos Alba del Carmen'
#  'Rios Duque Sandra Rafaela' 'GUAINÍA' 'ARAUCA'
#  'Velasquez Chica Enit Juliet' 'Oscar Romel Castellanos Virguez y Otro'
#  'ARCHIPIÉLAGO DE SAN ANDRÉS, PROVIDENCIA Y' 'VICHADA'
#  'Franco Emilio Ayala' 'CHOCÓ' 'Andres Felipe Orozco Vasquez'
#  'Anatilde Toro Echavarria' 'Lara Gomez Miguel Eduardo'
#  'Alicia Maria Velez Restrepo']
#
#
# Valores únicos en la columna "municipio_inmueble":
# ['TULUA' 'ARMENIA' 'MEDELLIN' 'SOACHA' 'GRANADA' 'BOGOTÁ, D. C.'
#  'VILLAVICENCIO' 'FLORIDABLANCA' 'MONTERIA' 'LA UNION' 'PASTO'
#  'SAN JOSE DEL GUAVIARE' 'CALI' 'CALDAS' 'MANIZALES' 'CAJICA' 'TURBACO'
#  'ENVIGADO' 'BARRANQUILLA' 'IBAGUE' 'PEREIRA' 'RIONEGRO' 'SABANETA'
#  'VALLEDUPAR' 'SANTA ROSA DE CABAL' 'SAN JERONIMO' 'ESPINAL' 'PIEDECUESTA'
#  'GIRARDOTA' 'YOPAL' 'SANTA MARTA' 'PUERTO COLOMBIA' 'ITAGUI' 'YARUMAL'
#  'JARDIN' 'CUCUTA' 'BARBOSA' 'RIOSUCIO' 'NEIVA' 'JAMUNDI' 'SAN MIGUEL'
#  'POPAYAN' 'MARIQUITA' 'SAN GIL' 'MARINILLA' 'CARTAGO' 'PALMIRA'
#  'COPACABANA' 'RETIRO' 'BELLO' 'DOS QUEBRADAS' 'CARTAGENA' 'RICAURTE'
#  'TUNJA' 'BUCARAMANGA' 'CAICEDONIA' 'FREDONIA' 'LOS PATIOS' 'CAMPOALEGRE'
#  'PATIA' 'SINCELEJO' 'GIRON' 'CERETE' 'SIMIJACA' 'LA ESTRELLA' 'COVEÑAS'
#  'CIENAGA' 'MADRID' 'PARAMO' 'LEBRIJA' 'FUSAGASUGA' 'APARTADO' 'DUITAMA'
#  'AGUACHICA' 'MOSQUERA' 'BUGA' 'TURBO' 'LA TEBAIDA' 'ZIPAQUIRA' 'EL PASO'
#  'AGUSTIN CODAZZI' 'PRADERA' 'VILLAMARIA' 'PAMPLONA' 'JERICO' 'CAJAMARCA'
#  'LA CEJA' 'FACATATIVA' 'CHIA' 'SEVILLA' 'SANTUARIO' 'ANDES' 'MAICAO'
#  'DON MATIAS' 'UBATE' 'COCORNA' 'EL CERRITO' 'SANTANDER DE QUILICHAO'
#  'SOGAMOSO' 'ARJONA' 'PUERTO SALGAR' 'CAUCASIA' 'SAN ANTONIO' 'DAGUA'
#  'LETICIA' 'PUERTO BOYACA' 'JUAN DE ACOSTA' 'PAZ DE ARIPORO' 'PAIPA'
#  'FLORENCIA' 'CANDELARIA' 'PALERMO' 'RESTREPO' 'PUERTO GAITAN' 'TOCANCIPA'
#  'YOTOCO' 'BARRANCABERMEJA' 'VILLETA' 'SOLEDAD' 'CIUDAD BOLIVAR'
#  'CHINCHINA' 'GUADALUPE' 'VILLANUEVA' 'GIRARDOT' 'PLANADAS' 'SAMANA'
#  'LA MESA' 'SABANAGRANDE' 'IQUIRA' 'SANTIAGO DE TOLU' 'MOCOA' 'EL PAUJIL'
#  'CHACHAGUI' 'CHIQUINQUIRA' 'GALAPA' 'CALARCA' 'IPIALES' 'PALESTINA'
#  'COTA' 'PUERTO ASIS' 'PAILITAS' 'OCAÑA' 'LA VEGA' 'PITALITO' 'ALCALA'
#  'MELGAR' 'ACACIAS' 'HONDA' 'SAN MARCOS' 'ROSAS' 'GARZON' 'PEÑOL'
#  'CONCORDIA' 'ROLDANILLO' 'CARMEN DE VIBORAL' 'VALLE DEL GUAMUEZ'
#  'Ochoa Vahos Alejandra' 'TIMBIO' 'GUAMO' 'SANTA BARBARA' 'ANDALUCIA'
#  'LA VICTORIA' 'BARANOA' 'ARMERO GUAYABAL' 'TOLU VIEJO'
#  'SANTAFE DE ANTIOQUIA' 'FLANDES' 'PLANETA RICA' 'SAN VICENTE DEL CAGUAN'
#  'LA ARGENTINA' 'CIRCASIA' 'BUENAVENTURA' 'FRONTINO' 'LENGUAZAQUE' 'OIBA'
#  'MALAGA' 'LA PLATA' 'MAGANGUE' 'GARAGOA' 'SABANA DE TORRES'
#  'VILLA DEL ROSARIO' 'LORICA' 'SOPO' 'SOPETRAN' 'CHAPARRAL' 'SIBUNDOY'
#  'EL DONCELLO' 'OBANDO' 'COROZAL' 'ALGECIRAS' 'SUPIA' 'SANTA ROSA DEL SUR'
#  'QUIMBAYA' 'SAN PEDRO' 'SUAZA' 'VILLAGARZON' 'PUERTO BERRIO' 'SUESCA'
#  'FUNZA' 'ENTRERRIOS' 'BRICEÑO' 'LA DORADA' 'VALPARAISO' 'ANAPOIMA'
#  'VILLA DE LEYVA' 'GACHANCIPA' 'SARDINATA' 'PUERTO TRIUNFO' 'LIBANO'
#  'SIBATE' 'ANTIOQUIA' 'EL PLAYON' 'LINARES' 'SAN DIEGO' 'CHINACOTA'
#  'SABANALARGA' 'RISARALDA' 'TARAZA' 'TENA' 'YUMBO' 'COROMORO' 'BOSCONIA'
#  'CHINU' 'CHARALA' 'MONTENEGRO' 'MIRANDA' 'EL BANCO' 'PUENTE NACIONAL'
#  'INIRIDA' 'ARAUCA' 'CHOCONTA' 'RIOHACHA' 'LEJANIAS' 'VALLE DE SAN JOSE'
#  'EL CAIRO' 'CHIRIGUANA' 'SANDONA' 'AGUAZUL' 'SAN ALBERTO' 'SUBACHOQUE'
#  'SILVIA' 'TAURAMENA' 'CASTILLA LA NUEVA' 'CAREPA' 'GUAMAL' 'CUNDINAMARCA'
#  'SAN ANDRES' 'MARMATO' 'PUERTO TEJADA' 'EBEJICO' 'TABIO' 'CUMARAL'
#  'LA CRUZ' 'BUGALAGRANDE' 'SAN PABLO' 'LERIDA' 'GUATAPE' 'PACORA' 'COPER'
#  'FILANDIA' 'PACHO' 'LA PAZ' 'SAN ANTONIO DE TEQUENDAMA' 'SAN AGUSTIN'
#  'EL RETORNO' 'RIVERA' 'SAN JOSE' 'VICTORIA' 'SUAN' 'GUARNE'
#  'PUERTO CARREÑO' 'MALAMBO' 'TOLEDO' 'AGUA DE DIOS' 'SOCORRO' 'PAEZ'
#  'TUMACO' 'PUERTO LLERAS' 'FONSECA' 'SAN MARTIN' 'MARSELLA' 'EL COPEY'
#  'ARIGUANI' 'ZARZAL' 'SAMACA' 'RAMIRIQUI' 'GUADUAS' 'PIENDAMO' 'CARAMANTA'
#  'TIBASOSA' 'TOCAIMA' 'EL BAGRE' 'SALDAÑA' 'BELALCAZAR' 'SASAIMA' 'SUPATA'
#  'VALENCIA' 'LA CALERA' 'ROVIRA' 'TUQUERRES' 'PUERTO RICO'
#  'PUERTO CAICEDO' 'PURIFICACION' 'BETULIA' 'LA CUMBRE' 'ANGELOPOLIS'
#  'AGUADAS' 'SAHAGUN' 'AMAGA' 'PENSILVANIA' 'TENJO' 'SALENTO' 'GAMARRA'
#  'DISTRACCION' 'CONDOTO' 'MANI' 'LA VIRGINIA' 'PLATO' 'NECOCLI'
#  'SANTA ROSA DE OSOS' 'TANGUA' 'SINCE' 'ANSERMANUEVO' 'CAMPO DE LA CRUZ'
#  'SAN VICENTE DE CHUCURI' 'GUACARI' 'CURITI' 'MOMPOS' 'TADO' 'SANTA MARIA'
#  'FUNDACION' 'PARATEBUENO' 'SESQUILE' 'SAN CARLOS' 'NARIÑO' 'MONTELIBANO'
#  'GUATAVITA' 'PUERTO WILCHES' 'SALADOBLANCO' 'FLORIDA' 'NILO' 'ACEVEDO'
#  'VILLAPINZON' 'SILVANIA' 'CAJIBIO' 'SANTO TOMAS' 'GINEBRA' 'MANAURE'
#  'VELEZ' 'VITERBO' 'EL CARMEN DE BOLIVAR' 'ANSERMA' 'TIERRALTA'
#  'PUERTO LOPEZ' 'GALERAS' 'CHINAVITA' 'MONIQUIRA' 'CARTAGENA DEL CHAIRA'
#  'ARATOCA' 'BETANIA' 'COYAIMA' 'ALVARADO' 'TRUJILLO' 'TIBU' 'CALIMA'
#  'OROCUE' 'SOTAQUIRA' 'QUIBDO' 'SOCHA' 'SAN ROSA VITERBO' 'ABREGO'
#  'GOMEZ PLATA' 'VENECIA' 'GUASCA' 'NOBSA' 'ABRIAQUI' 'SOATA' 'ANCUYA'
#  'TAUSA' 'SANTA ANA' 'DIBULLA' 'SAN SEBASTIAN DE BUENAVISTA' 'NORCASIA'
#  'BARICHARA' 'SAN ANTERO' 'PUEBLO RICO' 'GIGANTE' 'ARGELIA' 'BARRANCAS'
#  'PALMAS DEL SOCORRO' 'SAMPUES' 'ISNOS' 'BELEN DE UMBRIA' 'CHIGORODO'
#  'SAN PELAYO' 'TAMESIS' 'SIMACOTA' 'REMEDIOS' 'GACHETA' 'EL ROSAL'
#  'RIOFRIO' 'BOCHALEMA' 'SONSON' 'MARIA LA BAJA' 'MACHETA' 'NUEVO COLON'
#  'EL DOVIO' 'MONGUI' 'TELLO' 'COGUA' 'GUATICA' 'YAGUARA' 'CUBARRAL'
#  'EL TAMBO' 'TUTA' 'ACANDI' 'SALAZAR' 'VILLA RICA' 'MEDINA' 'PALOCABILDO'
#  'BUESACO' 'SAN JOSE DEL FRAGUA' 'RAGONVALIA' 'SACHICA'
#  'CARMEN DE APICALA' 'VISTA HERMOSA' 'MESETAS' 'LA PINTADA' 'FRESNO'
#  'AIPE' 'RIO DE ORO']
#
#
# Valores únicos en la columna "sector":
# ['Urbano' 'Rural' 'MEDELLIN' 'Villa Sofia' 'Urbanización Los Alcores'
#  'Bifamiliar Cortés' nan 'Poblado del Hato' 'Meseta de San Diego'
#  'Urb. Tierra Prometida P.H.' 'LOS GIRASOLES' 'Pie del Monte']
#
#
# Valores únicos en la columna "alcantarillado_en_el_sector":
# ['Si' 'No' '37172' '0' '4.3346261000000004']
#
#
# Valores únicos en la columna "acueducto_en_el_sector":
# ['Si' 'No' '5.0010106160500402E+23']
#
#
# Valores únicos en la columna "gas_en_el_sector":
# ['Si' 'No' '0']
#
#
# Valores únicos en la columna "energia_en_el_sector":
# ['Si' 'No']
#
#
# Valores únicos en la columna "telefono_en_el_sector":
# ['Si' 'No']
#
#
# Valores únicos en la columna "vias_pavimentadas":
# ['Si' 'No']
#
#
# Valores únicos en la columna "sardineles_en_las_vias":
# ['Si' 'No']
#
#
# Valores únicos en la columna "andenes_en_las_vias":
# ['Si' 'No']
#
#
# Valores únicos en la columna "estrato":
# ['3' '5' '4' '2' '1' '6' 'Industrial' 'Comercial' 'Si' 'No' 'Oficina']
#
#
# Valores únicos en la columna "barrio_legal":
# ['Si' 'No' '4' '3' '5' '6']
#
#
# Valores únicos en la columna "topografia_sector":
# ['Plano' 'Ligera' 'Inclinado' 'Accidentada' 'Si']
#
#
# Valores únicos en la columna "condiciones_salubridad":
# ['Buenas' 'Regulares' '3' 'Ligera' 'Inclinado' 'Malas' 'Plano']
#
#
# Valores únicos en la columna "transporte":
# ['Bueno' 'Regular' 'Malo' 'Si' 'Buenas']
#
#
# Valores únicos en la columna "demanda_interes":
# ['Media' 'Fuerte' 'Débil' 'Nula' 'Buenas' 'Vivienda' 'Hotelero']
#
#
# Valores únicos en la columna "paradero":
# ['No' 'Si' 'Bueno' 'Media' 'Fuerte']
#
#
# Valores únicos en la columna "alumbrado":
# ['Si' 'No' 'Vivienda']
#
#
# Valores únicos en la columna "arborizacion":
# ['Si' 'No' 'Media']
#
#
# Valores únicos en la columna "alamedas":
# ['No' 'Si']
#
#
# Valores únicos en la columna "ciclo_rutas":
# ['No' 'Si']
#
#
# Valores únicos en la columna "nivel_equipamiento_comercial":
# ['Bueno' 'Regular Malo' 'Muy bueno' 'En Proyecto' 'Si' 'No']
#
#
# Valores únicos en la columna "alcantarillado_en_el_predio":
# ['Si' '0' 'No'
#  '"La oferta es media, con demanda escasa. No se encuentran registros de actividad inmobiliaria en inmuebles similares al de avalúo."'
#  '"Equilibrio entre oferta y demanda"'
#  'con buena ubicación con respecto al sur de la ciudad."'
#  '"La oferta es baja y la demanda media."'
#  'Estables, es un sector muy consolidado con una sana y responsable mezcla de usos que se articula fácilmente a importantes ejes de movilidad ademas de sistemas de transporte publico.'
#  '"Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo. "'
#  '"El comportamiento de la oferta y la demanda es moderado. Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo."'
#  '"Constante para venta o para arriendo."'
#  '"Del análisis del segmento de mercado relativo a los inmuebles comparables que se valora se deduce que la oferta en la zona es media. Las características constructivas de la vivienda son similares a la media del mercado competitivo. Los precios varían según las zonas, el tamaño y antigüedad de la vivienda. La demanda de inmuebles similares en la zona satisface en plazos normales de mercado. En la actualidad la oferta existe es absorbida por la demanda. "'
#  '"Alta oferta por parte de las constructoras que están urbanizando la periferia urbana, al igual que la demanda por las vías proyectadas y su cercanía a Medellín."'
#  '"Dentro del conjunto se observa oferta de venta de inmuebles dispersa. Por el desarrollo de la zona, el equipamiento y calidad de redes de servicios, vías de acceso, y cercanía a centros de servicios e institucionales, se considera equilibrio entre la demanda a la oferta.   "'
#  'anotando que durante los últimos años ha ingresado al Municipio una oferta importante de inmuebles, que incide en el tiempo de comercialización."'
#  '"Vivienda Medianera de 1 piso, lote 90 m2, área construida 52 m2 (Según medido en visita'
#  '"Teniendo en cuenta el estado actual del inmueble y su localización en el sector, ésta se podrá dar en el mediano plazo."'
#  'Es un municipio que esta creciendo mucho por su creciente dinámica industrial sobre el corredor de la autopista, esto genera oferta y demanda en igual medida por parte de las poblaciones obreras que aumentan con el tiempo y requieren territorio dond'
#  '"Moderado para venta o para arriendo por el mercado al cual hace parte."'
#  'Es buena por ser un sector de transición de viviendas a lo comercial, centro médicos, oficinas y locales comerciales.'
#  '"Sector consolidado, sin construcciones en la actualidad."'
#  '"Existe un marcado equilibrio, en cuanto a estos factores nos referimos."'
#  '"Oferta: normal - alta, demanda con tendencia a moderarse."'
#  '"El zona se edifica vivienda multifamiliar"'
#  '"buenas acorde con la dinámica inmobiliaria del sector"'
#  '"En la zona se edifica vivienda unifamiliar y multifamiliar."'
#  'Media en ambos casos, en el sector toman lugar nuevos proyectos pero no son significativos, la demanda por su completa infraestructura y sana mezcla de usos del uso del suelo.'
#  '"Comportamiento 1:3, el sector tiene demanda alta por ser un sector tranquilo y acogedor."'
#  '"Debido a la situación de la vivienda en el entorno y al actual nivel de oferta y demanda en la zona, es de esperar un continuo proceso moderado de revalorización del inmueble. "'
#  '"Actualmente la actividad edificadora es buena, se encuentra planteado la construcción futura de proyectos de vivienda unifamiliar, en urbanizaciones abiertas de casas enfocadas a estratos 2 y 3"'
#  '"buenas, acorde con la dinámica inmobiliaria del sector"'
#  '"El comportamiento de la oferta y demanda es bueno para este sector tanto para vivienda usada como nueva."'
#  '"Actualmente la actividad edificadora es buena, se encuentran proyectos de vivienda multifamiliar en construcción de urbanizaciones abiertas enfocados para estrato 2 y 3 y conjuntos cerrados para estrato 2, 3 y 4."'
#  '"Apartamento Según Certificado de Tradición ÁC 84,58 m2, Según Escritura PH Á. Construida 84,58 m2, Área Privada 71,04 m2, Coef. 3%.  Área Parqueadero 13,86 m2, Coef. 0,49%. Ubicado en interior con balcón y vista a la piscina y áreas comunes. Consta de sala comedor, balcón, cocina tipo americano, cuarto de ropas con lavadero, baño social, dos habitaciones, una es la principal con baño privado. Piso Porcelanato. Construcción en Bloque H5. Vivienda Nueva, con excelentes acabados y enlucimiento."'
#  '"Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo."'
#  '"El comportamiento de la oferta y demanda es bueno para este sector tanto para vivienda usada como nueva multifamiliar."'
#  'aprovechando el buen urbanismo del barrio."'
#  '"Análisis del segmento de mercado relativo a los inmuebles comparables con el que se valora se deduce que la oferta en la zona es media. Las características constructivas de la vivienda valorada son similares a la media del mercado competitivo. La demanda de inmuebles similares en la zona se satisface en plazos normales de mercado."'
#  '"Es dinámica producto de la afluencia de personas de diferentes partes del departamento y del país quienes vienen atraídos por las nuevas fuentes económicas de producción."'
#  '"Debido a la situación de la vivienda en el entorno urbano y al actual nivel de oferta y demanda en la zona, es de esperar un continuo proceso moderado de revalorización del inmueble, las perspectivas de valorización del inmueble a medio plazo son medias. "'
#  '"Oferta alta por parte de los nuevos proyectos residenciales campestres que toman lugar ne la periferia urbana del municipio, y demanda alta por su cercanía a la ciudad de Medellin."'
#  '"Buenas, acordes con la dinámica inmobiliaria del sector"'
#  '"El mercado de vivienda en la zona es aceptable, destacando que durante los últimos años ha ingresado una oferta importante de apartamentos a Bello, que puede incidir en el incremento del tiempo esperado de comercialización de los inmuebles ubicados en este Municipio."'
#  '"Las perspectivas de valorización permanecen estables."'
#  '"Estable en ambos casos, la oferta se ve en los diferentes conjuntos que componen el sector ademas de los nuevos proyectos que tomaran lugar en los predios remanentes, y la demanda por ser un sector aislado del centro de la ciudad mas no lejano de el mismo, ademas cuenta con excelente infraestructura y cercanía a importantes comercios."'
#  '"Dentro del sector se observa casi en su totalidad viviendas de dos pisos antiguas, sin embargo, por ser tan cercano al perimetro urbano, (zona de expansión) hay varios terrenos sin desarrollar y se observa inicio de construcción de proyectos en edifciios de apartamentos similares. El conjunto en esta primera etapa se encuentra completamente terminado, está en desarrollo de obra la segunda etapa. El apartamento se encuentra completamente terminado, con todos sus acabados, nuevo. "'
#  '"Sector consolidado, con construcciones de proyectos de apartamentos."'
#  'Oferta baja por su grado de consolidación, crece en zonas periféricas en desarrollo, la demanda es mayor por su sana y responsable mezcla de usos del suelo y completa infraestructura en proceso de actualización.'
#  '"En la zona se amplían, re-modelan y sub-dividen las viviendas, dado que es un sector consolidado."'
#  '"La oferta es baja, con demanda baja. No se encuentran registros de actividad inmobiliaria en inmuebles similares al de avalúo."'
#  '"En la actualidad  la oferta es absorbida por la demanda "'
#  '"Debido a la situación de la vivienda en el entorno urbano, al actual nivel de oferta y demanda en la zona, es posible considerar un continuo proceso moderado de valorización el inmueble o perspectivas de valorización a mediano plazo"'
#  'El mercado de vivienda en la zona es bueno por el equilibrio existente entre  oferta y demanda.'
#  'El sector posee una tendencia residencial por excelencia, la composición de las viviendas ubicadas en el mismo permiten el éxito comercial de las ventas, con buenos precios y con cortos plazos."'
#  '"Oferta baja por el alto grado de consolidación y baja actividad constructiva, se ven inmuebles en venta dentro de los conjuntos ya establecidos pero son pocos, la demanda es mayor sin embargo pocas personas tienen la capacidad económica para adquirir inmuebles de estas características."'
#  '"Buenas, acorde con la dinámica inmobiliaria del sector"'
#  '"buenas acorde con la dinámica inmobiliaria del sector."'
#  '"Actualmente la actividad edificadora es buena, se encuentran proyectos de vivienda multifamiliar en construcción de urbanizaciones abiertas enfocados para estrato 2 y 3 y conjuntos cerrados para estrato 3 y 4."'
#  '"en el sector se edifica zona residencial para uso de vivienda multifamiliar"'
#  '"sector residencial, edificado para vivienda multifamiliar"'
#  'o se encuentra congelada."'
#  '"Buena cerca se adelanta la construcción de soluciones de vivienda estrato 2"'
#  '"Buena, cerca se adelanta la construcción de soluciones de vivienda estrato 2."'
#  '"Buena , cerca a la urbanización se adelanta la construcción de conjuntos de vivienda estrato 2, como Portal del Rio y Montecarlo. "'
#  '"Se encuentran viviendas con similares características de diseño, y construcción, dentro del conjunto. En este sector se respira aire de tranquilidad, por estar en Conjunto Cerrado. En el conjunto existen ofertas de venta en este momento, existen algunas personas interesadas en comprar en Flandes, por haber nuevos proyectos con mejores expectativas. "'
#  '"buenas acordes con la dinámica inmobiliaria del sector."'
#  '"LA DEMANDA ES BUENA, COMO QUIERA QUE HAY INTERES DE COMPRADORES E INVERSIONISTAS. LA OFERTA ES VARIADA, Y SE CONSIGUEN LOCALES,  APARTAMENTOS Y OFICINAS. "']
#
#
# Valores únicos en la columna "acueducto_en_el_predio":
# ['Si' 'No' '0'
#  '"En crecimiento: multifamiliares en torres de mas de 20 pisos'
#  'Baja, es un barrio con un alto grado de consolidación de la ciudad donde quedan pocos predios con unidades de vivienda unifamiliar que puedan ser reemplazadas por proyectos residenciales mas densos.'
#  'En promesa de compraventa y Licencia de Construcción aparece AC 54 m2). Consta de antejardín, sala-comedor, cocina, dos (2) habitaciones, baño social, lavadero y patio de ropas. Pisos en cemento. Cubierta teja de fibrocemento sobre entramado metálico, SIN cielo raso, construcción en bloque H5 sin pañetar, puertas y ventanas metálicas. Pdte. Instalar Sanitario. REGULAR Estado Conservación. VIVIENDA NUEVA."'
#  '"Es un sector en consolidación, al momento de la visita se observó actividad edificadora nueva en la zona."'
#  '"Del análisis del segmento de mercado relativo a los inmuebles comparables que se valora se deduce que la oferta existe es absorbida por la demanda,  y la demanda de inmuebles similares en la zona se satisface en plazos normales de mercado."'
#  '"buena, acorde con la dinámica inmobiliaria del sector"'
#  '"Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo. "'
#  '"El sector del Inmueble está en crecimiento, Y cuenta con la construcción múltiples proyectos de conjuntos residenciales que se realizan en la actualidad."'
#  '"El comportamiento actual de la oferta y demanda es bueno para éste sector, especialmente para vivienda usada."'
#  '"El comportamiento de la oferta y demanda es bueno para este sector tanto para vivienda usada como nueva."'
#  '"En el Conjunto existen ofertas de venta en este momento, igualmente existen varias personas interesadas en comprar, por tratarse de la zona residencial de crecimiento en Girardot, cerca de UNIMINUTO, por la avenida que conduce al municipio de Tocaima (Cundinamarca) cerca de Unicentro, cerca del centro del Municipio. En el sector se ha visto un desarrollo urbanístico, es tranquilo, con zonas verdes, lo que permite que el inmueble tenga una alta valorización. "'
#  '"ARA CONDOMINIO CLUB CL 51 19 68 Aptos con área de: 96,89 mt2 - ARKANTO K 23 51 62 Aptos con área de: 85,45 mt2 - BOTICELLI APARTAMENTOS K 23 52 37 Aptos con área de: 78,70 mt2 - INFINITY SKY CLUB CL 54 K 27 Aptos con área de: 78,43 mt2 - PALLADIO CONDOMINIO K 23 52 51 Aptos con área de: 68,00 mt2  y QATAR APARTAMENTOS CL 48 23 26 Aptos con área de: 91,00 mt2'
#  '"Sector consolidado, y con la construcción de  un proyecto nuevo de apartamentos."'
#  '"Sector consolidado, con la construcción de un proyecto de apartamentos cerca."'
#  '"El sector se ha consolidado con casas y aptos característicos de estrato 4 y 5, la actividad edificadora es buena, se destacan construcciones de casas grandes de 2 pisos y torres de aptos de 5 y 10 pisos, en lotes de terreno sometidos bajo Propiedad Horizontal. "'
#  '"Dentro del conjunto no observa amplia oferta de venta de inmuebles dentro de esta primera etapa, está vedida casi en su totalidad. se encuentra en oferta de venta la segunda etapa del conjunto. Se observa oferta de venta en otros proyectos similares dentro del municipio. Por su localización equipamiento comunal y cercanía a centros de servicios e institucionales, se considera superior la demanda a la oferta.   "'
#  '"La oferta y la demanda están equilibras"'
#  '"Se observa en el sector la construcción de viviendas unifamiliares de uno y dos pisos."'
#  '"Sector en crecimiento, con proyectos de vivienda en construcción."'
#  '"buenas acordes con la dinamica inmobiliaria del sector"'
#  '"buena acorde con la dinámica inmobiliaria del sector"'
#  '"Se construyen varios proyectos en el sector desde el estrato 3 al estrato 5'
#  '"La demanda y oferta actualmente con comportamiento similar. Sin embargo los tiempos de comercialización son lentos."'
#  '"La demanda y oferta tienen comportamiento similar. Sin embargo los tiempos de comercialización son lentos."']
#
#
# Valores únicos en la columna "gas_en_el_predio":
# ['Si' 'No' '0' 'se adelanta un proyecto de este tipo en proximidad."'
#  'Estable en ambos casos, la oferta por su grado de consolidación, se ven inmuebles en venta pero de manera puntual, la demanda es constante por su buena mezcla de usos del suelo y cercanía a importantes equipamientos.'
#  '"En la urbanización existen Varias ofertas de venta en este momento por parte de la Constructora, igualmente existen varias personas interesadas en comprar, por tratarse de una urbanización nueva, a pocas cuadras de la vía hacia El Guamo, cercano al matadero municipal. En el sector se ha visto un desarrollo urbanístico, y tranquilo, con zonas verdes'
#  '"Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo. Se presenta cierta demanda de inmuebles nuevos o recién construidos que satisfacen en periodos relativamente cortos el mercado. Actualmente la oferta es absorbida por la demanda de estos inmuebles en la medida en que salen al mercado."'
#  '"Comportamiento Oferta y Demanda. Del análisis del segmento de mercado relativo a los inmuebles comparables que se valora se deduce que la oferta existe es absorbida por la demanda,  y la demanda de inmuebles similares en la zona se satisface en plazos normales de mercado. "'
#  'PRECIO PROMEDIO MT2: $3.613.381,00"'
#  '"Del análisis del segmento de mercado relativo a los inmuebles comparables que se valora se deduce que la oferta existe es absorbida por la demanda,  y la demanda de inmuebles similares en la zona se satisface en plazos normales de mercado."'
#  '"El comportamiento de la oferta y la demanda es moderado. "'
#  '"Del análisis del segmento del mercado relativo a inmuebles comparables con el que se valora deducimos que hay equilibrio entre oferta y demanda en el sector. Las cacterísticas constructivas del inmueble valorado, son similares a las del mercado competitivo."'
#  '"Del análisis del segmento del mercado relativo a inmueble comparables con el que se valora deducimos que hay buena demanda en el sector. Las características constructivas del inmueble valorado, son similares a las del mercado competitivo. "'
#  'zona que anteriormente era de uso rural hoy urbana']
#
#
# Valores únicos en la columna "energia_en_el_predio":
# ['Si' 'No' '0'
#  '"Se mantiene en equilibrio gracias al crecimiento en construcciones en la zona y por la construcción que se adelanta de un centro comercial."'
#  'lo que permite que el inmueble tenga una moderada valorización. "'
#  '"DEMANDA: MEDIA - OFERTA: ALTA"'
#  'todo el desarrollo es nuevo, una nueva ciudad."']
#
#
# Valores únicos en la columna "telefono_en_el_predio":
# ['No' 'Si' '0' '"OFERTA: MEDIA - DEMANDA: BAJA"']
#
#
# Valores únicos en la columna "tipo_inmueble":
# ['Casa' 'Apartamento' 'Casa Rural' 'Oficina' 'Finca' 'Lote' 'No'
#  'Conjunto o Edificio' 'Si' '0' 'Depósito' 'Garaje' 'Lote Urbano']
#
#
# Valores únicos en la columna "uso_actual":
# ['Vivienda' 'Turismo' 'Otro' 'Sin uso - Vivienda' 'V. Multihabitacional'
#  '0' 'No' 'Si' 'VER ANEXOS INFORME.' 'Comercio'
#  'ESPACIOS PARA CUATRO PERSONAS' 'Salud' 'Trifamiliar' 'Bodega' 'Oficina'
#  'Ind. Otras' 'Construcción Viviendas' 'Ind. Madera y Muebles' 'Casa'
#  'Apartamento' 'Parqueadero' 'Ver informe' 'PATIO, BAÑERA, ZONA LIBRE'
#  '2a. Vivienda' 'PATIO DE ROPAS, ALBERCA LAVADE' 'Educación'
#  'Ind. Textil y Cuero' 'Ind. Química' 'Sin uso - Eriazo' 'Iglesia'
#  'Hotelero' 'Lote']
#
#
# Valores únicos en la columna "clase_inmueble":
# ['Unifamiliar' 'Multifamiliar' 'Bifamiliar' 'Viv. Subdividida' '0' 'Otro'
#  'Comercial' 'Apartamento' 'VER ANEXOS INFORME.'
#  'BUENAS COND PARA HABITAR' 'Casa' 'Vivienda' 'Ver informe'
#  'Sin uso - Vivienda' 'Ed. Oficinas' '3 HABITACIONES, ALBERCA LAVADE'
#  'Residencial' 'DOS HABITACIONES, COCINA SENCI' 'desocupado'
#  'servicios con un solo' 'Si' 'Sin uso - Eriazo']
#
#
# Valores únicos en la columna "sometido_a_propiedad_horizontal":
# ['No' 'Si' 'Arrendatario' 'SinOcupante' '0' 'Multifamiliar' 'Propietario'
#  'VER ANEXOS INFORME.' 'ropas, 3 alcobas, 4 baños,' 'Otro' 'Unifamiliar'
#  'para cinco personas aprox.' 'SinInformacion' 'Ver anexos informe.'
#  'Vivienda']
#
#
# Valores únicos en la columna "antejardin":
# ['No Aplica' 'Aplica' '0' '3' '2']
#
#
# Valores únicos en la columna "predio_subdividido_fisicamente":
# ['No' 'Si' '0' '1,8' 'Aplica' '2' 'Resultante' '3' '2,7' '1,67'
#  'No Aplica' '0,11' '2,1' '0,8' '2,5' '0,7' '1,5' '1,7']
#
#
# Valores únicos en la columna "contadores_agua":
# ['0' '2' '1' '3' 'Aplica' '4' 'Resultante' '6' '5' 'No' '2,2' '1,5' '7'
#  '92' 0 1 2]
#
#
# Valores únicos en la columna "contadores_luz":
# ['0' '2' '1' '3' 'No' '4' '6' '5' 'Aplica' '92' 0 1 2]
#
#
# Valores únicos en la columna "accesorios":
# ['0' '2' '1' '3' 'No' '4' '5' '7' '6' '46' 0 2 1 3 4]
#
#
# Valores únicos en la columna "area_valorada":
# ['131' '254.98' '82' ... '143,81' '14.611.000.000.000.000' '29.68']
#
#
# Valores únicos en la columna "numero_piso":
# ['0' '1' '99' '9' '7' '5' '11' '2' '17' '10' '6' '13' '14' '3' '16' '4'
#  '12' '15' '8' '20' '30' '27' '19' '21' '18' '25' '22' 'Construccion' '29'
#  '23' '97' '91,42' '37' '24' '31'
#  'unidad abierta sin cobro de administración."' 'Terreno' '26' '54'
#  '40,52' '28' '32'
#  '"Área del terreno tomada de los documentos suministrados, el área de la construcción es tomada en sitio encontrándose que cuenta con la normatividad del sector. "'
#  '36'
#  '"El inmueble se encuentra en buen estado en el momento de la visita"'
#  '"No se presentan diferencias entre lo físico y lo jurídico. "'
#  'altura permitida de 4 pisos"' '98' '54,2'
#  '"El inmueble se encuentra en aparente buen estado, ubicado en un sector de expansión con desarrollo en vivienda y crecimiento en altura. Para el presente avalúo se valora el área medida en la inspección, la cual es susceptible de ser legalizada, es decir, se encuentra dentro de lo permitido por la normativa del sector."'
#  '"Cumple normativa sector 6, plan parcial aprobado. El inmueble cuenta con un área de terreno de 65 m2, según consta en los documentos suministrados'
#  '"Apartamento Según Certificado de Tradición ÁC 84,58 m2, Según Escritura PH Á. Construida 84,58 m2, Área Privada 71,04 m2, Coef. 3%.  Área Parqueadero 13,86 m2, Coef. 0,49%. Ubicado en interior con balcón y vista a la piscina y áreas comunes. Consta de sala comedor, balcón, cocina tipo americano, cuarto de ropas con lavadero, baño social, dos habitaciones, una es la principal con baño privado. Piso Porcelanato. Construcción en Bloque H5. Vivienda Nueva, con excelentes acabados y enlucimiento."'
#  'sin embargo. presenta unas pequeños fisuras en las paredes y pisos que pueden ser producto del mismo uso del predio."'
#  '56,85' '80,22'
#  '"El conjunto cuenta con 6 torres, 5 pisos y 60 apartamentos en total. La Unidad cuenta no cuenta ascensor.  "'
#  '34' '98,22'
#  '"Es un inmueble que hace parte de un conjunto residencial desarrollado por sistema de edificios de apartamentos, levantada por sistema tradicional de vigas y columnas en concreto. Localizado dentro de la primera etapa del conjunto residencial conformado por 8 torres de apartamentos, cada torre de cinco pisos. El apartamento cuenta con dos parqueaderos privados y un depósito. El conjunto residencial cuenta con buenas áreas y equipamiento comunales, varios de estos espacios ya conformados."'
#  '"Según medidas tomadas en sitio, en P1 = 65,4 m2, P2 = 72,9 m2, P3 = 32,84 m2. Para un área total construida  de 171,14 m2. Pero al aplicar la norma, tiene un área susceptible de ser legalizada de 157,23 m2. Discriminados así: P1 = 56,7'
#  '"La vivienda es medianera construida en un piso, cuenta con un lote cuya proporción de frente y fondo es 0.124 dado que su frente tiene 5,50 ml y su fondo 40,5 ml  "'
#  '94' '50'
#  'área de actividad residencial neta. El lote del inmueble tiene un área registrada en títulos y corroborada por medición en sitio de 91.46. El área construida encontrada en sitio por medición con cinta métrica manual y digital de 116.10 (Piso 1 = 47.60M2 + Piso 2 = 54.40M2 + Terraza = 14M2). "'
#  'la diferencia entre el área de la medición y el área valorada es de 37,55 M2 que no se han tenido en cuenta para el justiprecio."'
#  'cada uno de los apartamentos tiene un parqueadero y hay 15 adicionales para visitantes. El conjunto presenta portería, piscina y jacuzi y salón comunal. "'
#  '52,44' '54,66'
#  '"Cumple normativa sector 6, plan parcial aprobado El Inmueble se conserva en las características de acabados y áreas entregadas por constructora."'
#  '"el inmueble se encuentra en buen estado en el momento de la visita"'
#  '"No existe construcciones dentro del lote"'
#  '"El inmueble, trata de un lote de terreno libre de construcción, ubicado  dentro de la Urbanización Villa Coralsa. El inmueble puede disponer de los servicios, dado que los mismos están aprobados para la urbanización. "'
#  '" No existe construcciones dentro del predio"'
#  'pisos en cemento rustico, baño con enchapes en piso y pared, independientes ducha y sanitario. Cubierta en placa de concreto. Apartamento Recién construido para estrenar. Regulares acabados. Buenas áreas comunes como salón y piscinas. Conjunto se encuentra en construcción."'
#  '45' 6 0 1 2 3 5 12 9 14 4 7 8 11 20 16 10 15 24 81 26 13 28 18 22 17]
#
#
# Valores únicos en la columna "numero_de_edificios":
# ['0' '1' '2' '8' '18' '5' '22' '24' '4' '3' '15' '6' '12' '28' '20' '9'
#  '13' '10' '14' '60' '7' '43' '32' '71' '21' '80' '76' '11' '26' '19' 'No'
#  '47' '25' '17' '16' '99' '79' '30' '74' '27'
#  '"No se presenta diferencias entre lo físico y lo especificado con la promesa de compraventa ( SE ENTREGA EN GENERAL SIN ACABADOS.)"'
#  '45' '40' '42' '29' '34' 'Construccion' '36' '50' 'Si' '56' '90' '23'
#  '66' '62' '75' '61' '53' '35' '81' '92' '54' '96' '88' '38'
#  '"Vivienda Medianera de 1 piso, lote 90 m2, área construida 52 m2 (Según medido en visita'
#  '48' '44' '63' '98' '72' '39' '49' '33' '70' '83' '64' '69' '86' '46'
#  '84' '77' '78' '31' '37' '97' '93' '55' '52' '57' '85' '68' '94'
#  '"Consta de: sala, comedor, sala de estudio, cocina integral, patio de ropas con baño, mirador o terraza cubierta, tres alcobas de las cuales dos (2) tienen baño privado, un (1) baño auxiliar, terraza dentro de la cual se encuentra un estadero cubierto con machihembre, y teja española, una pequeña alcoba que sirve de ropas. Inmueble en regular estado'
#  '41' '82' '65' '89'
#  'el balcón con área de 4,24 m2 y el patio con área de  4,77 m2.  El conjunto cuenta con 14 torres de 5 pisos, y 265 apartamentos en total'
#  '70,35' '58' '87' 7 0 1 38 12 10 3 26 2 6 15 4 8 17 23 19 20 24 5 84 16
#  48 30 32 9 98 22 14 25 18 34 13 81 21 60 93 11 40 56 53]
#
#
# Valores únicos en la columna "rph":
# ['0' 'Si' 'No' 'Vivienda' 'Residencial' '999' '15,5' 'VIVIENDA'
#  'residencial' '0,299' 'VIVIENDA E INSTITUCIONAL' 'Vivienda Campestre'
#  'vivienda multifamiliar' 'Residencial Neta' '0,55' '2' '0,1'
#  'Vivienda Recreativa' '0,43' 'vivienda' 'Consolidación Urb. Resid.'
#  '0,54' 'Interior' '4']
#
#
# Valores únicos en la columna "porteria":
# ['0' 'Si' 'No' '0,061' 'Residencial' 'residencial' 'vivienda' 'Vivienda'
#  'VIVIENDA' 'Exterior' '265' 'vivienda multifamiliar' 'Interior']
#
#
# Valores únicos en la columna "citofono":
# ['0' 'Si' 'No' 'RESIDENCIAL' 'Vivienda' '6' '0,38' '68']
#
#
# Valores únicos en la columna "bicicletero":
# ['0' 'No' 'Si' 'VIVIENDA' '17,38' 'Residencial' '1356']
#
#
# Valores únicos en la columna "piscina":
# ['0' 'Si' 'No' 'R-2' 'Vivienda' 'MULTIHABITACIONAL']
#
#
# Valores únicos en la columna "tanque_de_agua":
# ['0' 'Si' 'No' 'VIVIENDA UNIFAMILIAR' 'RESIDENCIAL T 1 Y 2']
#
#
# Valores únicos en la columna "club_house":
# ['0' 'No' 'Si']
#
#
# Valores únicos en la columna "garaje_visitantes":
# ['0' 'Si' 'No']
#
#
# Valores únicos en la columna "teatrino":
# ['0' 'No' 'Si']
#
#
# Valores únicos en la columna "sauna":
# ['0' 'No' 'Si']
#
#
# Valores únicos en la columna "vigilancia_privada":
# ['No' 'Si' '0']
#
#
# Valores únicos en la columna "tipo_vigilancia":
# ['0' '24 Horas' '12 Horas' 'No' 'Si']
#
#
# Valores únicos en la columna "administracion":
# ['0' 'Si' 'No' '24 Horas' '12 Horas']
#
#
# Valores únicos en la columna "vetustez":
# ['45' '0' '8' '13' '27' '2' '32' '14' '11' '9' '19' '35' '5' '10' '28'
#  '17' '16' '23' '1' '25' '4' '39' '3' '24' '6' '7' '12' '31' '20' '33'
#  '15' '38' '26' '22' '30' '41' '47' '18' '34' '49' '37' '57' '40' '21'
#  '36' '52' '2017' '29' '48' '61' '43' '46' '1965' '42' '59' '55' '50' '44'
#  '1994' '60' 'Si' '53' '2013' '56' '2007' '64' '51' '79' '54' '2016'
#  '1980' '58' '68' '65' '62' '66' '1999' '2005' '1990' '1985' '76' '63'
#  '67' '2008' '1995' '1996' '69' '1987' '-90' '2010' '2012' '1974' '2004'
#  '1986' '2018' '1997' '2003' '""' '74' '1998' '72' '71' '78' '1993' '2006'
#  '1981' 'No'
#  '"LICENCIA  N° 68276-2-16-0101 modificada con la RESOLUCION N° 0171 del 29/11/2016"'
#  '825' '1992' '70' '1989' '1988' 0 29 15 14 6 32 7 17 24 38 4 12 2 3 22 1
#  40 5 28 25 13 33 21 20 8 10 39 16 26 18 49 19 36 34 35 30 47 31 11 9 23
#  63 27 37 59 43 50 61 41 53 60 58 55]
#
#
# Valores únicos en la columna "pisos_bodega":
# ['2' '1' '0' '52' '23' '30' '4' '10' '37' '1981' '18' '12' '27' '32' 'Si'
#  '22' '21' '1989' '2017' '7' '2007' '1988' '5' '43' '13' '31' '2009' '11'
#  '20' '14' '9' 'No' '2014' '19' '1985' '2016' '24' '1999' '1998' '36'
#  '2008' '2013' '25' '28' '29' 1 2 0]
#
#
# Valores únicos en la columna "estructura":
# ['Muro de carga' 'Tradicional' 'Mamposteria Estructural' 'Industrializada'
#  'Otros' '1' '2' 'Metalica' '0' '2000' '36' '2015' '28' '10' '29' '2011'
#  '8' '2008' '3' '2010' '2007' '32' '2001' '18' '2017' '19' '2012' '5' '9'
#  '4' 'Si']
#
#
# Valores únicos en la columna "ajustes_sismoresistentes":
# ['No disponible' 'No Reparados' 'Reparados' 'Tradicional'
#  'Mamposteria Estructural' 'Muro de carga' '2017' '17' 'Industrializada'
#  '2' '0' '1' '6' '9' '5' '7' '10' '16' '18']
#
#
# Valores únicos en la columna "cubierta":
# ['Teja de barro' 'Placa concreto imp.' 'Otros' 'Teja fibrocemento'
#  'Teja metálica' 'Teja plástica' 'No disponible' 'No Reparados' '0' '1'
#  'Mamposteria Estructural' '2017' 'Reparados' 'Tradicional' '2013'
#  'Muro de carga' '4']
#
#
# Valores únicos en la columna "fachada":
# ['Graniplast' 'Pañete y pintura' 'Ladrillo a la vista' 'Otros'
#  'Concreto Texturado' 'Flotante' 'Teja fibrocemento' 'Placa concreto imp.'
#  'Teja de barro' '1' 'Teja metálica' 'Tradicional' 'No disponible' '0'
#  'Industrializada' 'Mamposteria Estructural' 'Reparados' '1994'
#  'No Reparados' '4' '2016']
#
#
# Valores únicos en la columna "tipo_fachada":
# ['Mayor a 6 metros' 'De 3 a 6 metros' 'De 0 a 3 metros' 'Pañete y pintura'
#  'Ladrillo a la vista' 'Otros' 'Industrializada' 'Graniplast'
#  'No disponible' 'Teja de barro' '1' 'Teja plástica' 'Placa concreto imp.'
#  'Teja fibrocemento' '23' 'Teja metálica' 'Concreto Texturado']
#
#
# Valores únicos en la columna "estructura_reforzada":
# ['No disponible' 'Trabes coladas en sitio' 'No tiene trabes'
#  'Trabes prefabricadas' 'De 0 a 3 metros' 'De 3 a 6 metros'
#  'Mayor a 6 metros' 'Teja de barro' 'Pañete y pintura' 'Tradicional'
#  'Placa concreto imp.' 'Ladrillo a la vista' 'Teja fibrocemento' '2'
#  'Flotante' 'Graniplast' 'Industrializada' '1' 'Otros']
#
#
# Valores únicos en la columna "danos_previos":
# ['Sin daños previos' 'No disponible' 'Con daños previos' 'No tiene trabes'
#  'Placa concreto imp.' 'Pañete y pintura' 'Trabes coladas en sitio'
#  'De 3 a 6 metros' 'Ladrillo a la vista' 'Mayor a 6 metros'
#  'Mamposteria Estructural' 'De 0 a 3 metros']
#
#
# Valores únicos en la columna "material_de_construccion":
# ['Mampostería' 'Concreto Reforzado' 'Adobe, bahareque o tapia'
#  'Mixtas u Otro' 'Madera' 'No existe' 'No disponible' 'Pañete y pintura'
#  'Mayor a 6 metros' 'Sin daños previos' 'Teja fibrocemento' 'Acero'
#  'Trabes coladas en sitio' 'No tiene trabes' 'De 3 a 6 metros'
#  'De 0 a 3 metros' 'Placa concreto imp.']
#
#
# Valores únicos en la columna "iluminacion":
# ['Bueno' 'Regular' '0' 'Mampostería reforzada' 'Muros' 'No tiene trabes'
#  'Pórticos' 'Malo' 'Sin daños previos' 'Mampostería no reforzada'
#  'Mampostería' 'No disponible' 'De 3 a 6 metros' 'Mampostería confinada'
#  'Paneles prefabricados' 'Ladrillo a la vista' 'Pórticos no arriostrados'
#  'Concreto Reforzado' 'Mixtas u Otro' 'Adobe' 'Sistema dual o combinado'
#  'Pórticos arriostrados' 'Mayor a 6 metros' 'Concreto Texturado'
#  'No existe']
#
#
# Valores únicos en la columna "ventilacion":
# ['Bueno' 'Regular' 'Sin daños previos' 'Malo' 'Concreto Reforzado'
#  'Mampostería no reforzada' 'Trabes coladas en sitio'
#  'Mampostería reforzada' 'Mampostería' 'Mayor a 6 metros'
#  'Sistema dual o combinado' 'Pórticos' 'Mixtas u Otro'
#  'Mampostería confinada' '0' 'No disponible' 'Pórticos arriostrados']
#
#
# Valores únicos en la columna "irregularidad_planta":
# ['Con irregularidad' 'No disponible' 'Sin irregularidad' 'Bueno'
#  'Concreto Reforzado' 'Pórticos no arriostrados' 'Sin daños previos'
#  'Mampostería no reforzada' 'Paneles prefabricados'
#  'Mampostería confinada' 'Trabes coladas en sitio' 'Mampostería reforzada'
#  'Regular' '0']
#
#
# Valores únicos en la columna "irregularidad_altura":
# ['Sin irregularidad' 'No disponible' 'Con irregularidad' 'Muros' 'Bueno'
#  'Mampostería' 'Sin daños previos' 'Concreto Reforzado']
#
#
# Valores únicos en la columna "habitaciones":
# ['3' '4' '6' '1' '2' '5' '10' '0' '24' '7' '12' '9'
#  '"Estructura tradicional en aparente buen estado de conservación."' '13'
#  '"Presenta una parte de la construcción en bahareque con un 20% aproximado de la construcción total."'
#  '"Durante la inspección física no se observan a simple vista problemas estructurales que hagan temer por la estabilidad del inmueble."'
#  '8'
#  '"Estructura en muro de carga, de dos pisos, en buen estado, no presenta  daños a la vista."'
#  'Bueno'
#  '"Estructura en concreto reforzado cumpliendo con las dimensiones minimas que exige el P.O.T., en general el inmueble està bien construido."'
#  '"En lo que se pudo visualizar se observa una estructura aparentemente estable que permite la habitabilidad sobre el mismo."'
#  'Sin irregularidad'
#  '"Estructura tradicional con fachada en pañete y pintura. "'
#  '"El inmueble presenta un  buen estado de conservación,  mantenimiento y distribución en su diseño, no se observaron daños ni fisuras. Cuenta con una buena ventilación e iluminación interior, se encuentra ubicado en un sector residencial."'
#  '"estructura en buen estado."'
#  '"Estructura fabricada con mampostería reforzada con dovelas de hierro dispuestas en vértices y aristas, losa aligerada con adobe y cubierta con vigas y alfardas de madera."'
#  '"Torres de apartamentos construidos por sistema tradicional de vigas y columnas en concreto reforzado, con acabados en ladrillo a la vista trabado en sitio, placa en concreto maciza de entrepiso, teja de asbesto cemento sobre perfilería metálica."'
#  '"Estructura en aparente buen estado."'
#  '"El presente avalúo no contiene cálculos estructurales, por tratarse de un estimado de valor."'
#  '"No  presenta  daños  a  simple  vista."' '14'
#  'Armazón en bloque de cemento reforzado con dovelas de acero en vértices y aristas, escaleras vaciadas y cubierta con losa aligerada donde funciona la terraza.'
#  '"Superficialmente no se aprecian problemas estructurales, el primer piso es construido en mampostería, mientras el segundo piso es prefabricado, con revoque exterior y drywall al interior."'
#  'El inmueble tiene cimientos, columnas y vigas de amarre.'
#  '"Estructura en aparente buen estado de conservación."'
#  '"Inmueble con vigas, columnas, placa de entrepiso y escaleras en concreto armado."'
#  'Con irregularidad' 'con pantallas, columnetas y vigas de amarre."'
#  '"Este informe no constituye un estudio técnico desde el punto de vista de patología estructural, sismo resistencia o geotécnica. No se evidencian en las construcciones señales que hagan sospechar sobre daños estructurales ni deficiencias."'
#  '"En aparente buen estado de conservación debido a que es nuevo. No se observan fallas evidentes en el momento de la inspecciòn. "'
#  '"Etructura en aparente buen estado."' '"Estructura en buen estado."'
#  '"Inmueble con vigas y columnas en concreto armado."' '11'
#  '"estructura sismo resistente, sin daños previos al momento de la visita"'
#  'Mampostería reforzada con dovelas de hierro en vértices y aristas, losa aligerada con adobe y cubierta con vigas y alfardas de madera.'
#  '"El inmueble presenta un  buen estado de conservación,  mantenimiento y distribución en su diseño, no se observaron daños ni fisuras. Cuenta con una buena ventilación e iluminación interior, se encuentra ubicado en un sector residencial. "'
#  '"Casa de un piso de estructura aporticada en ferroconcreto, con muros en de arcilla pañetados y estucados"'
#  '15'
#  '"La estructura se encuentra en aparente buen estado de conservación."'
#  '32'
#  'Sistema estructural de  pórtico  de concreto reforzado,  de ocho  pisos, en aparente buen estado de  conservación y mantenimiento.'
#  'LA ESTRUCTURA SE OBSERVO EN BUEN ESTADO. NO PRESENTA GRIETAS, NI FISURAS.'
#  '"estructura sismo resistente, sin daño previo y en buen estado a la hora de la visita"'
#  '"En aparente buen estado, fachada en pañete y pintura, estructura en mampostería."'
#  'No disponible'
#  '"Se trata de un conjunto en aparente buen estado de mantenimiento."'
#  '"La vivienda es usada y terminada en excelente estado, con tipo de construcción moderna."'
#  'La estructura se observó en buen estado, no hay grietas o fisuras.'
#  '"Estructura industrializada con fachada en graniplast. "'
#  'Sistema dual o combinado'
#  'se observa deterioro en los acabados de piso y paredes."'
#  '"La edificación no posee fisuras, ni grietas que pongan en duda la Estabilidad del inmueble."'
#  '"La vivienda es usada y terminada en buen estado, con construcción estructural."'
#  '"Pórticos de concreto reforzado con losa aligerada con caceton de madera "'
#  '"Estructura en mampostería con fachada en pañete y pintura. Se encuentra en aparente buen estado."'
#  '"Estructura sismo resistente sin daños previos al momento de la visita."'
#  '"El presente avalúo no contiene cálculos, por tratarse de un estimado de valor."'
#  '"Edificación nueva, aún sin ocupación. El parqueadero del edificio es a nivel de semi sótano. "'
#  '26'
#  '"Estructura tradicional de pórticos de concreto reforzado con losa aligerada con cacetones y cubierta con vigas y alfardas de madera."'
#  '"Estructura en ferro concreto y mampostería estructural en Bloque H5, reforzada con columnas, que dan estabilidad a la construcción."'
#  '"Estructura sismo resistente, sin daños previos al momento de la visita."'
#  'Estructura tradicional de pórticos de concreto reforzado  y mampostería reforzada con dovelas en vértices, con vigas y alfardas de madera en cubierta.'
#  'la unidad objeto de este análisis ha sido objeto de revisiones preventivas por parte de las Autoridades Municipales ."'
#  '"En aparente buen estado."'
#  '"Aparentemente no presenta problemas geológicos sobre el terreno. Tampoco se encuentra en zona de riesgo."'
#  'La estructura aparenta buen estado.'
#  'El presente avalúo no contiene cálculos estructurales, por tratarse de un estimado de valor.'
#  '"el día de la visita tecnica se pudo observar que el inmueble se encuentra en buen estado."'
#  '"Estructura tradicional con fachada en ladrillo a la vista. "'
#  '"La estructura del inmueble se encuentra en aparente buen estado."'
#  '"El día de la visita técnica se pudo observar que el inmueble se encuentra en buen estado."'
#  'Cimientos y vigas de amarre en concreto reforzado'
#  '"Estructura tradicional de pórticos de concreto reforzada con vigas y columnas de grandes proporciones que le permite tener espacios con amplias luces "'
#  '20'
#  '"estructura sismo resistente en buen estado al momento de realizar la visita"'
#  '"estructura sismo resistente, sin daños previos al momento de la visita."'
#  '22'
#  '"estructura sismo resistente sin daños previos al momento de la visita"'
#  '"LA ESTRUCTURA SE OBSERVO EN BUEN ESTADO"' 3 4 5 0 2 1 6 7 9 10]
#
#
# Valores únicos en la columna "estar_habitacion":
# ['1' '0' '2' '6' '3' '4' 'Sin irregularidad'
#  '"superficialmente no se aprecian problemas estructurales."' 'Bueno' '5'
#  '"Estructura en mampostería con fachada en pañete y pintura."'
#  '"Estrucutura sismo resistente sin daños previos al momento de la visita"'
#  '"Estructura mampostería con fachada en ladrillo a la vista. "'
#  '"La estructura del inmueble se encuentra en buen estado."'
#  '"Se observa en aparente buen estado su estructura."' 'No disponible'
#  '"Cimentación Concreto reforzado con Placa aligerada soportado sobre terreno natural. Columnas estructurales, entrepisos con placa maciza concreto reforzado. Muros en bloque hueco de arcilla H5."'
#  '"El inmueble cuenta con una estructura tradicional con muros en pantallas y columnas, fachada en vidrio, tiene una buena ventilación e iluminación natural al interior."'
#  '"Presenta una buenas características que se denotan en el buen estado general del inmueble."'
#  '"Estructura en buen estado."'
# ...
#  '4,15' '2' '4.2' '2.4300000000000002' '2.78' '2,13' '3,27'
#  '17.600000000000001' '2,51' '7.2' '6,5' '3.44' '2.31' '2.97' '44000000'
#  '6.44' '2.5299999999999998' '3.31' '4.21' '1.47' '3.15' '5.98' '2.87'
#  '3.1' '1,95' '2,44' '75885516' '3,73' '3.18' '2.36' '1.1299999999999999'
#  '3.97' '2.0699999999999998' '1.3' '3.13' '2,96' '4.84' '2,14' '4,94'
#  '3,14' '1.51' '15000000' '2.0099999999999998' '2.3199999999999998' '3.53'
#  '17500000' '3.34' '12600000' '15,02' '1,35' '2.56' '2.11' '3,36' '2.62'
#  '2.94' '3.08' '6.25' '0,86' '4,12' '2.57' '6.3' '1.98' '3.72' '1.9'
#  '3.26' '3.14' '4,07' '1.49' '8.41' '10,75' '6.23' '5.25' '9,9' '1.58'
#  '6.9' '2,55' '1.59' '6,16' '0.98' '5.88' '2.5499999999999998' '4.62'
#  '4,78' '21527000,00' '1,17' '2.15' '3.6' '2.91' '0.81' '7.65' '1.93'
#  '3,84' '4.68' '2.92' '4.88' '4,51' '1.88' '1,89' '2.2999999999999998'
#  '2.23' '13,25' '15.2' '2.16' '3.91' '2.66' '2.54' '3.09' '2,65' '5,88'
#  '1.0900000000000001' '1,33' '4.5999999999999996' '3,18' '135500000,0'
#  '34,51' '5,47' '5.33' '3,92' '6,82' '1,9' '3.9' '2,85' '18.45' '1,44'
#  '4,57' '4.3' '4.25' '2,45' '4.99' '2.14' '1.1000000000000001' '2.98'
#  '12,41' '2,9' '2,2' '1.94' '18000000' '2,73' '3.23' '3,8' '5.71' '5,15'
#  '3.27' '2,46' '1.62' '3.42' '4.7' '13,86' '11.73' '3.56' '2.52'
#  '4.9000000000000004' '2,6' '1.55' '2.93' '0,96' '1.97' '23040000,00'
#  '1.63' '0,76' '3.16' '2.84' '1,62' '20000000' '1.71' '2.75' '3.73' '1,57'
#  '3.66' '3,03' '2.5099999999999998' '10,48' '4.87' '1.29' '1.52' '1.56'
#  '6,1' '1.61' '2.46' '3,08' '3,21' '1,93' '4,5' '5.1100000000000003'
#  '3,69' '1.78' '167139000,00' '4,11' '5.2' '3,1' '6.1' '235846800,00'
#  '35000000' '4,38' '14.99' '8.81' '4.57' '2.2200000000000002' '1,96'
#  '3,72' '1.74' '2,1' '1.36' '3.8' '2.42' '6' '13.65' '2.85' '2.17' '1,2'
#  '50000000' '6.07' '1,72' '2.25' '4.51' '1.33' '7' '1,29' '14,4' '4.93'
#  '4.45' '1.45' '1.65' '3.68' '4,16' '5.49' '0,9' '2.13' '1,66' '3,45'
#  '148090600,0' '7.8' '3.64' '1,46' '8.34' '4,79' '3,79' '3,31' '4.83'
#  '2,54' '2,32' '4,8' '2,07' '5,17' '2,34' '5,07' '1.27' '6,63' '3.71'
#  '3.55' '2.96' '5.48' '3,94' '4.78' '1,13' '3.4' '1.67' '4.01' '6,03'
#  '1.89' '2,25' '1.92' '2,88' '5,3' '3,19' '3,05' '4,73' '3,23' '1.34'
#  '1,56' '11.1' '1,03' '4,35' '1,3' '4.04' '2,86' '5,76' '2,43' '4.91'
#  '0.59' '6.42' '0.88' '2,3' '1.81' '4.08' '2.71' '3.63' '2,84' '6.79'
#  '4.33' '4.47' '5,58' '3,06' '4,01' '7,38' '5.61' '1,1' '12000762,00'
#  '1,74' '6,17' '7.23' '1.32' '4.76' '1.07' '2.19' '10,35' '4,68' '3,67'
#  '2.04' '43000000' '40000000' '5.29' '60413000,00' '2.79' '4.05' '4.95'
#  '9.9499999999999993' '0.52' '3,33' '125856000,00' '1.23' '2,03' '1.31'
#  '3,58' '4,1' '14999068,00' '3.02' '1.43' '6,0' '5.65' '1.24' '24,75'
#  '2.72' '5.04' '5.99' '1.75' '1,08' '5,25' '15.5' '9.24' '0.65' '5,37'
#  '3.93' '5,78' '2,18' '3.07' '4.1100000000000003' '3.49' '3.43'
#  '2.4900000000000002' '1,67' '1,12' '5,32' '2,7' '2.34' '1,34' '3.58'
#  '4,56' '0.8' '5,1' '1.53' '2.0299999999999998' '0.95' '5,56' '6.69'
#  '5.86' '6.92' '22080000,00' '4.82' '2.77' '2,08' '4,9' '44,35' '2.39'
#  '6.32' '2,8' '1.57' '3.39' '3.76' '5.42' '4,88' '2.69' '6.43' '4,39'
#  '24750000,00' '11.85' '2,64' '7.49' '3.61' '2,27' '3,7' '1,87' '1,85'
#  '24.900.000.000.000.000' '5.19' '2,62' '2,24' '5.5' '3,28' '1.2' '1,47']
#
#
# Valores únicos en la columna "valor_area_deposito":
# ['0' '2500000' '6000000' '4000000' '3000000' '2099200' '5000000' '2475000'
#  '2000000' '3500000' '2950000,00' '6730000,00' '4500000' '3934000'
#  '3120000' '3999240' '8000000' '2487100' '5150000' '870000,00' '3960000'
#  '3312000' '7002900' '99587280,0' '3000000,0' '3021308,00' '2112000'
#  '17400000,0' '2873000,00' '1648000,00' '3905000,00' '1,98' '6564010,00'
#  '7776000,00' '2500330,00' '3999840' '4140000' '16000000' '6920000'
#  '20000000' '3252000' '2520000,0' '6760000' '1500000' '10320000,00'
#  '7000000'
#  'viviendas con similares características de diseño y construcción, dentro de la urbanización.  Se toma en cuenta el método de comparación o de mercado y de reposición. "'
#  '9240000' '3000001,55' '9,81' '8000000,0' '3880000,00' '24000000'
#  '3800000' '3200000' '3300000' '9370000' '2400000' '15000000' '6500000'
#  '3185000' '2520000' '3600000' '6017500,00' '7140000' '2780000'
#  '2130000,00' '17000000' '3965800,00' '9750000,0' '4550000' '3623400'
#  '3280000' '2,78' '6192000' '5060000' '1000000' '8372000' '3730000,00'
#  '3000000.1386000002' '1130000' '2600000' '5500000' '4940000,00' '1,79'
#  '2025000,00' '3360000,00' '5056800' '5008000' '4992680' '860000,00'
#  '3000100' '3912000' '4884000,00' '2384000' '8410000' '4020000,00'
#  '2910000' '10890000,0' '3002000' '10000000' '1800000' '2156000' '4002000'
#  '2580000' '8730000' '1930000' '6912000,00' '4000400' '3068000' '5368000'
#  '11160000' '2880000,0' '5499000' '2676000' '25000000' '5865000'
#  '5000800,00' '12818500' '2970000' '7740000' '4680000' '3420000,00'
#  '4600000,00' '3450000' '2200000' '14892000,00' '2900000,0' '4000032'
#  '3800000,0' '3460000' '3690000,00' '15246000,00' '5340000' '2015000'
#  '1852500,00' '1596000,00' '3384000' '4290000' '5000940,00' '3002000,0'
#  '3500001,00' '4545000,00' '26200000,00' '1560000' '2412500,00' '3900000'
#  '12' '3468000' '4650000,0' '5694000,00' '9000000' '2574000' '5000400'
#  '4250000,0' '3441000' '3506600' '4900000,00' '3216000' '3250000'
#  '2100000,0' '4000780' '2.7' '4042000,00' '11250000,0' '4590000,00'
#  '3625000' '4999999995' '3834000' '2490000,00' '3174000' '4000000,0'
#  '3998800' '4519500,00' '6390000,00' '8500000' '2000700,0' '5040000'
#  '4002240,00' '8444190' '3480000,00' '8640000,0' '3440000,00' '4212000,00'
#  '4972500,00' '6900000' '5400000' '1130000,00' '7600000' '5760000,00'
#  '4306500,00' '30000000008' '3740000' '3402000,00' '2540000' '6990000'
#  '8148000' '5958000' '3213000,00' '2250000' '4010000,00' '3080000,0'
#  '3360000' '3,18' '3520000,00' '2040000' '3094000,00' '3000000.0040000002'
#  '4680000,00' '3589000' '3626000,00' '2,64' '32,17' '3847500' '3645000'
#  '1965000' '5012000,00' '3020000' '2860000' '54,66' '3780000' '2820000,00'
#  '1356000,00' '3078000' '40000000' '4350000' '4352000' '1960000,00'
#  '1180000,00' '15500000' '4998000' '4932000' '5868000' '5576000'
#  '1503000,00' '9730000' '2700000,0' '1340000,00' '2026000' '4491000,00'
#  '1950000' '3000480,00' '950000' '8028000' '12000000' '2050000' '3100000'
#  '3700000' '71625250,00' '13000000' '2058000' '4553040,00' '6725000'
#  '7024000,00' '11850000' 0 6000000 3000000 5000000 4500000 2000000 2270000
#  3263000 5500000 4440000 2220000 4000000 11400000 2300000 5904000 9000000
#  3800000 3340000 4500160 1938000 2500000]
#
#
# Valores únicos en la columna "area_terreno":
# ['253,4' '0' '104' ... '1732,09' '128.68' '15.236.000.000.000.000']
#
#
# Valores únicos en la columna "valor_area_terreno":
# ['63350000,0' '0' '27040000' ... '64960000' '322100000' '59420400']
#
#
# Valores únicos en la columna "area_construccion":
# ['131,15' '0' '84.52' ... '106.65' '206,88' '29.68']
#
#
# Valores únicos en la columna "valor_area_construccion":
# ['81968750,00' '0' '69306400' ... 39600000 23447200 58240000]
#
#
# Valores únicos en la columna "area_otros":
# ['0' '157' '120' '46.94' '74.75' '555' '253' '209.77' '102' '36,3' '38'
#  '66456000' '2847' '360' '527.52' '1804.22' '72' '46.9'
#  '35.200000000000003' '13.4' '339.15' '84' '2515.11' '115.72' '79' '340,2'
#  '91800000,0' '1.23' '47740000' '56' '23,45' '5.59' '219.38' '82.6' '1510'
#  '101.45' '60' '41.2' '2236' '60.5' '60,45' '42' '518' '136' '1106' '150'
#  '516' '140' '90,62' '146' '110' '1362.49' '77' '48.87' '64,4' '133,33'
#  '62.106999999999999' '460' '941' '90.09' '52.5' '46656000,0' '381.78'
#  '80' '143' '317941000,00' '75,24' '17' '71840000,0' '68.849999999999994'
#  '601.20000000000005' '49' '141762000,00' '100485000,00' '2431' '69,6'
#  '219.5' '274,83' '160.08000000000001' '55' '105' '266,68' '49.5' '78'
#  '10.199999999999999' '30' '53820000' '1382.55' '7.4' '39.81' '427.56'
#  '129375000,00' '42,93' '71800176,00' '165,13' '620.54'
#  '79.400000000000006' '5.84' '35,69' '107.64' '406' '91.69' '162' '337,29'
#  '2315,85' '46800000' '5461.26' '15,26' '87.98' '15' '49024000,00'
#  '1800,43' '217.24' '36.020000000000003' '111.37' '1500,04' '5.94'
#  '508.82' '65' '106.6' '84.5' '250' '96' '459,48' '466.84' '84.13' '222'
#  '47.94' '343.56' '2882.57' '130' '290979000,00' '1676.23' '54' '218.98'
#  '237.64' '76.5' '128.69999999999999' '33' '557,3' '216000000' '1988,84'
#  '158,52' '52953600,0' '1137.1400000000001' '701.62' '6470.74' '79.8'
#  '1652.59' '49,5' '54,72' '152' '125.5' '64.58' '42.75' '57.24' '142,1'
#  '39.57' '34.369999999999997' '36' '66' '12' '69' '46,37' '80.92' '11842'
#  '258' '133' '32.549999999999997' '98' '88,05' '110250000,0' '48' '101,25'
#  '93.22' '92.11' '1007,37' '37.5' '23,54' '46,92' '902,62' '365.2'
#  '101,68' '328482000,00' '106,2' '72.09' '43.01' '56,7' '5520' '104'
#  '324,41' '274572000,0' '51,75' '36.729999999999997' '12.91' '44.57'
#  '88686672,0' '112' '13.75' '25020000,00' '12.5' '50' '49360524,0'
#  '182,56' '500' '2' '542.91999999999996' '75' '1796' '22032000' '63,05'
#  '12.07' '640.70000000000005' '53' '88' '18,05' '45' '4.08' '61.6' '6500'
#  '109350000' '46.32' '91.3' '853.51' '36.799999999999997' '182' '40,83'
#  '16.100000000000001' '97,25' '113,4' '1.61' '340.2' '35.15' '344.5'
#  '19.850000000000001' '60383400,00' '1' '182,28' '423,09' '25000000'
#  '7.35' '103.18' '71.28' '5,81' '99,8' '4019,26' '64,11' '528' '96.52'
#  '60750000' '770.11' '191,56' '56725110,00' '56.91' '141' '24.69' '102.17'
#  '38647004,00' '289.70999999999998' '228' '227.82' '573.9' '211.25'
#  '875,1' '64.709999999999994' '126' '9,01' '70,02' '842' '96795000,0'
#  '381.66' '40' '631,08' '28224000' '91,46' '2,17' '444,92' '197.75'
#  '296.87' '72,45' '563200000,0' '67,45' '168997500,00' '2.74' '800'
#  '45180000,00' '76.23' '73.17' '14' '106,59' '513.28' '63.55' '262,36'
#  '64.489999999999995' '364574000' '741' '94.5' '9' '116' '4.57' '23.83'
#  '224,25' '113.75' '206,01' '68' '46,9' '121.5' '50,9' '6,5' '1220,9'
#  '287' '118' '23,83' '45.19' '2023.86' '95,9' '70,35' '135' '380,8'
#  '1037.3499999999999' '25' '84525000,0' '7' '703' '64.8' '1500.91' '408'
#  '71.05' '9,16' '117681200,00' '16.420000000000002' '79.03' '652.4'
#  '215.6' '96.71' '1087' '129' '202.81' '351' '5.27' '3,6' '243' '6.02'
#  '30.26' '516.75' '6,25' '95,2' '124576500,00' '115.97'
#  '72.569999999999993' '130.4' '1509' '230.74' '236.68' '87,6' '148' '62.1'
#  '348.23' '75.239.999.999.999.900' '90.75' '8' '907.88' '121,5' '99.97'
#  '13.73' '182.1' '15.419.999.999.999.900' '127.08' '152.6' '1656,37'
#  '15.97' '90']
#
#
# Valores únicos en la columna "valor_area_otros":
# ['0' '78500000' '183600000' '70410000' '34160750' '333000000' '126500000'
#  '314655000' '98940000' '56628000,0' '13680000' '534990000' '7200000'
#  '584808672' '306717400' '54000000' '39396000' '26400000' '20100000'
#  '254362500' '122040000' '52500000' '905439600' '119191600' '63200000'
#  '57834000,0' '1230000' '30520000' '23450000,00' '1677000' '263256000'
#  '99120000' '196300000' '30435000' '39600000' '47664000' '8240000'
#  '335400000' '38700000' '54450000' '24180000,00' '31500000' '30000000'
#  '233100000' '96254000' '199080000' '79500000' '202469628' '92400000'
#  '26279800,00' '35000000' '103800000,70' '115811650' '58800000' '40000000'
#  '29322000' '77280000,0' '120930310,00' '18632100' '368000000' '374250000'
#  '58558500' '10500000' '33000000' '484860600' '74400000' '278850000'
#  '41382000,00' '17' '30982500' '150300000' '36750000' '66960000'
#  '291720000' '80000000' '153120000,0' '33840000' '548750000'
#  '137415000,00' '40800000' '419409600' '61600000' '213344000,00'
#  '49599000' '50700000' '25920000' '20400000' '44000000' '988523250'
#  '5920000' '14928750' '209504400' '53662500,00' '156873500,00' '179956600'
#  '35730000' '6424000' '41043500,00' '53820000' '771840000' '128457690'
#  '45360000' '505935000,00' '509487000,00' '600738600' '32503800,00'
#  '140768000' '75000000' '288068800,00' '41160000' '434480000' '34219000'
#  '189329000' '180000000' '142503800,00' '23760000' '677785000' '91000000'
#  '262236000' '31265000' '68750000' '52800000' '200838708,00' '653576000'
#  '67304000' '321900000' '76704000' '429450000' '893596700' '169000000'
#  '159241850' '18900000' '229929000' '477752000' '41310000' '128700000'
#  '42900000' '1192110000,0' '576763600,00' '93447540,00' '386627600'
#  '110154340' '550012900' '55860000' '347043900' '49401000,0' '47606400,00'
#  '67200000' '85500000' '30998400' '67972500' '51516000' '109576000,0'
#  '37195800' '52250000' '35676060' '72600000' '16800000' '75210000'
#  '31067900,00' '56644000' '10260000' '53760000' '672573000' '118680000'
#  '146300000' '32550000' '47040000' '42264000,00' '61440000' '60750000,00'
#  '156609600' '60239940' '594348300,00' '18000000' '24999480,00'
#  '53488800,00' '20475000' '551072000,00' '427284000' '71176000,00'
#  '106200000,0' '40370400' '21600000' '49461500' '76941900,0' '165600000'
#  '50400000' '49920000' '10800000' '87420700,00' '36225000,00' '60604500'
#  '9037000' '58200000' '60169500' '39000000' '72755200' '11000000'
#  '13000000' '50000000' '15000000' '128522240,00' '115544000' '30294000'
#  '6200000' '146588400' '37500000' '1' '646560000' '87040000' '75975250,00'
#  '9776700' '293086000' '212000000' '57200000' '13934600,00' '45000000'
#  '2652000' '59197600' '3900000' '78744000' '57062500' '298728500'
#  '22080000' '282100000' '34705500,00' '22218000' '28688750,00' '36000000'
#  '39120000,0' '2576000' '71442000' '17223500' '516750000' '112000000'
#  '142800000' '29775000' '98,22' '140684160,00' '171112000,00' '8085000'
#  '12000000' '113498000' '147050640' '2300760,00' '44910000,0'
#  '422022300,00' '57600000' '89250000' '60904500,00' '316800000' '84455000'
#  '157,23' '191222000' '126429600,00' '53900000' '39837000' '38400000'
#  '214320000' '29628000' '45976500' '77439' '91125000' '17382600'
#  '38160000' '223440000' '17280000' '672069000' '516510000' '348562500'
#  '158733000,0' '59986170' '69300000' '13515000,00' '42012000,00'
#  '14400000' '155770000' '1144980000' '487193760,00' '50' '73168000,00'
#  '8246000,00' '311444000,00' '158200000' '108000000' '109841900'
#  '44100000' '52526250,00' '45500000' '21780000' '54634500,00' '2285160'
#  '280000000' '105197400' '113413500' '10000000' '213180000,00' '252533760'
#  '114390000' '419776000,00' '48367500' '133380000' '93600000' '37800000'
#  '5400000' '96000000' '14060000' '46400000' '2742000' '100800000'
#  '46468500' '89700000,00' '147875000' '144207000,00' '9600000' '84048000'
#  '91630000' '52560000' '23450000,0' '170100000' '41229000,0' '3900000,0'
#  '262990000,0' '325745000' '59000000' '46468500,00' '99418000' '62400000'
#  '809544000' '45073000,0' '232155000,00' '81000000' '348432000,0'
#  '207470000' '3750000' '67080000' '25000000' '21000000' '64800000'
#  '456950000' '31752000' '56000000' '525318500' '75600000' '265200000'
#  '113680000' '13740000,00' '24758076' '27660500' '189196000' '118580000'
#  '82203500' '217400000' '103200000' '141967000' '280800000' '28560000'
#  '22000000' '9486000' '105300000' '3843000,0' '449400000' '3612000'
#  '10591000' '46980000' '775125000' '2187500,00' '138325600,0' '218400000'
#  '185552000' '70030050' '84760000' '1131750000' '184592000' '39,37'
#  '118340000' '70080000,0' '109200000' '162800000' '18630000' '53200000' 0
#  90539800 41382000 45375000 5200000 590122000 182250000 49985000 8238000
#  343258500 231300000 127080000 72800000 99190000 480347300 24641710
#  67500000]
#
#
# Valores únicos en la columna "area_libre":
# ['0' 'No' 'Si' '71' '184' '91,8' '77' '120' '57,6' '244,57' '89,8'
#  '152,25' '207,2' '69' '112,50' '88,12' '60' '80,95' '65,87' '103,73'
#  '223,83' '67,2' '54,72' '122,5' '84,58' '189,00' '50,04' '50,1' '54'
#  '63,74' '70,29' '53,87' '70,02' '119,5' '160,95' '242.12' '72,62' '85,26'
#  '49,23' '73,5' '44,35' '138,15']
#
#
# Valores únicos en la columna "valor_area_libre":
# ['0' '3258000' '5809648' ... 29478000 6210000 8085000]
#
#
# Valores únicos en la columna "valor_total_avaluo":
# ['145318750,00' '713986654' '270500000' ... '183290000,00' '154500000' nan]
#
#
# Valores únicos en la columna "Longitud":
# ['0.0' '-75.661152' '-75.5841161' ... '-740.423.059' '-7.415.561'
#  '-755.580.294']
#
#
# Valores únicos en la columna "Latitud":
# ['0.0' '4.5440265' '6.2770197' ... '4.920.316' '4.569.585' '63.179.324']

# %%
# Iniciando con las columnas que corresponden a estado o calidad, dado que tienen criterios específicos por lo que se pueden eliminar todos los registros que no cumplen estos criterios
list(df_concatenado['estado_acabados_pisos'].unique())
# Out:
# ['Bueno',
#  'Sin acabados',
#  'Regular',
#  '"Espacios funcionales ventilados e iluminados."',
#  '"Primer piso: sala, comedor, cuatro alcobas, cocina, un baño y zona de ropas. Segundo piso (nivel inferior): dos alcobas, un baño, cocina, patio descubierto y solar."',
#  '"El inmueble goza en general de buena distribución e iluminación. su distribución así: sala, comedor, cocina, zona de ropas,  baño social, 3 alcobas,  espacio para futuro baño"',
#  '"Hay buena distribución de dependencias, con espacios amplios."',
#  '0',
#  '"Buena distribucion, ventilacion e iluminacion natural. El Antejardin es utilizado como garaje de motos."',
#  '"La unidad que conforma la vivienda cuenta con dependencias necesarias para el uso al que se encuentra sometido. Al igual de manera básica presentan funcionalidad sobre el inmueble mismo. La unidad compuesta por el apartamento solo alcoba y baño. "',
#  '"Buena distribución de las dependencias. "',
#  '"Bien inmueble con una adecuada distribución. "',
#  '"el inmueble cuenta con buena distribución."',
#  '"Por sus tres frentes todas están bien iluminadas y ventiladas naturalmente, la alcoba principal tiene grandes dimensiones, tiene un su interior un jacuzzi ademas de baño privado balcón y vestier."',
#  '"Espacios funcionales, ventilados e iluminados."',
#  '"El inmueble cuenta con buena distribución."',
#  '"El inmueble solo cuenta con un baño."',
#  '"Presenta  buena  iluminación  y  ventilación."',
#  'Malo',
#  'Todas bien iluminadas y ventiladas por vanos en fachada y patio interno.',
#  'en 2 piso 3 aptos cada uno con sala, comedor cocina, ropas, baño y 2 alcobas',
#  '"Dependencias de buen tamaño y estado de conservación, la distribución del inmueble no es la mas conveniente dado que varias habitaciones estan comunicadas entre si y en algunos casos no se tiene puertas lo que disminuye la privacidad."',
#  'Dependencias con buena iluminación y ventilación.',
#  '"El inmueble goza en general de buena distribución e iluminación. su distribución así: sala, comedor, cocina, zona de ropas, balcon, baño social, estudio, 3 alcobas, 4 closets, 1 baño privado, alcoba y baño de servicio.   "',
#  '"Inmueble con espacios adecuados para su habitabilidad, la casa cuenta con un garaje interno cubierto."',
#  '"Consta de: Salón sala comedor, cocina integral, zona de ropas con lavadero, una alcoba con closet y un baño privado. Tiene garaje para moto asignado por escritura pública RPH"',
#  '"El inmueble objeto de estudio posee amplias zonas de distribución y buena iluminación."',
#  '"Con espacios suficientes para uso residencial"',
#  '"El apartamento 406 de la torre 2, tiene: sala, comedor, balcón, zona de oficios, cocina, baño social y alcoba."',
#  '"Inmueble con espacios buenos para su habitabilidad. La casa tiene un deposito y 2 garajes cubiertos."',
#  '"dependencia con buena iluminacion natural"',
#  '"El apartamento 402 de la torre I, tiene: sala, comedor, balcón, zona de ropas, cocina, baño social, 2 alcobas auxiliares y alcoba principal con baño privado."',
#  'Todas bien iluminadas y ventiladas por vanos en las dos caras de la fachada, por destacar sus amplios espacios sociales.',
#  '"Casa sin remodelación, con el antejardin cubierto y enrrejado."',
#  '"La vivienda consta de: terraza exterior, sala, comedor, cocina, un baño social, tres alcobas, área de labores en el patio interior."',
#  'segundo piso: habitacional independiente, con dos alcobas, cocina, baño general y sala comedor',
#  'Buena distribución de la dependencia, lo que permite la  iluminación y ventilación.',
#  'CUENTA CON ESPACIOS AMPLIOS Y VENTILADOS, Y LA VISTA ES SOBRE LA BAHIA DE CARTAGENA. LOS ACABADOS SON: PISO EN PORCELANATO, PAREDES ESTUCADAS Y PINTADAS, CLOSETS EN MADECOR, VENTANAS EN VIDRIO Y ALUMINIO, CIELO RASO EN DRYWALL.',
#  '"dependencias con buena iluminación natural en buen estado."',
#  'Piso 2: Baño y 2 alcobas',
#  '"El inmueble es esquinero y se encuentra subdividido en casa y apartaestudio con accesos independientes. "',
#  '"El inmueble goza en general de buena distribución e iluminación. su distribución así: sala, comedor, estudio, balcón, cocina, zona de ropas, baño social, 3 alcobas, 4 closet y  1 baño privado"',
#  '"Cuenta con una distribución arquitectónica acorde a su área."',
#  '"Cuenta con muy buena distribución de las dependencias, el cual cuenta con parqueadero dentro de la vivienda, con capacidad para dos vehículos."',
#  'Cuenta con una buena distribución interna que le permite ventilación e iluminación natural.',
#  '1',
#  '"El inmueble objeto de estudio posee amplias zonas de distribución y buena iluminación "',
#  '"La casa cuenta con 5 alcobas, sala, comedor, cocina, baño social, baño familiar, 2 baños privados, zona de lavado, terrraza  y antejerdìn."',
#  '"Buena distribución interna y posee porche con cerramiento."',
#  '"Buena distribución de las dependencias, para las suplir las necesidades suficientes de una familia promedio."',
#  '"Todas bien iluminadas y ventiladas por tener frente en sus cuatro caras, ademas la fachada principal tienen vanos de grandes proporciones."',
#  '"Buena distribución de las dependencias."',
#  '"Dependencias con buena iluminación natural."',
#  '"El apartamento solo cuenta con un baño."',
#  '"Cocina, comedor y sala integrados, sin divisiones internas. Habitaciones desarrolladas en torno  a dicho conjunto."',
#  '"Todas muy bien iluminadas y ventiladas por grandes vanos dispuestos sobre las dos frentes de la fachada"',
#  '"Garaje a la entrada de la vivienda sobre el andén, Sala, cocina, Comedor, tres habitaciones, todas con closet y la principal con baño privado',
#  'adicionalmente cuenta con 1 beneficiadero de cafe"',
#  'el Apto cuenta con vista al interior y exterior del conjunto. "',
#  '"Dependencias con excelente iluminación natural."',
#  'Proporcionales y naturalmente iluminadas y ventiladas por vanos y puertas vidrieras dispuestas sobre dos caras de la fachada, por destacar la generosa área social que se integra al jardín en la parte trasera.',
#  '"El inmueble cuenta con buena distribución de sus espacios."',
#  '"Las dependencias cuentan con una adecuada distribución."',
#  'el Apto cuenta con vista al interior y exterior del conjunto."',
#  'Sala-comedor, cocina y baño // Segunda planta',
#  '"Vivienda muy amplia, con espacios apropiados y bien distribuidos. Las bodegas hacen parte integral de la vivienda."',
#  '"El inmueble tiene buena distribución en sus dependencias y se encuentra en buenas condiciones."',
#  'El estudio es convertible a alcoba.',
#  'El inmueble cuenta con buena distribución de sus espacios.',
#  '"el inmueble cuenta con todas las dependencias"',
#  'de espacios amplios con buena iluminación y ventilación."',
#  '"El apartamento cuenta con 3 alcobas, la principal con baño, sala comedor, cocina, estudio,  baño social,  balcòn en alcoba principal y  sala comedor, zona de ropas, Parqueadero y  un depósito."',
#  '"el inmueble cuenta con todas las dependencias."',
#  'Se desarrollan tres (3) apartamentos en cada piso; el primer piso con acceso independiente y los otros dos con acceso por escaleras independiente. No hay RPH; los servicios públicos con un solo contador. Áreas bien distribuidas.',
#  'Se realiza una inspección de estas y se nota claramente que se encuentran completamente en obra blanca."',
#  '"Todas correctamente iluminadas y ventiladas, con generosos espacios de almacenamiento y armarios"',
#  '"dependencia en buen estado con muy buena iluminación natural"',
#  '"dependencias amplias con suficiente iluminación natural."',
#  'de espacios amplios con buena iluminación y ventilación. "',
#  '"Inmueble sub-dividido, que consta de en el primer piso una casa y un alcoba con baño y en el segundo piso un apartamento con terraza."',
#  '"Las dependencia se encuentran con buena iluminación natural y en buen estado"',
#  'Apto 1: Comedor, un baño, dos alcobas, cocina y patio de ropas. Segundo piso',
#  '"EL APARTAMENTO TIENE VISTA HACIA LA AVENIDA SAN MARTIN Y HACIA LA CALLE 10"']

# %%
criterios_estado_piso = ['Bueno', 'Sin acabados', 'Regular', 'Malo']
train_data.drop(train_data[~train_data['estado_acabados_pisos'].isin(criterios_estado_piso)].index, inplace=True)
test_data.drop(test_data[~test_data['estado_acabados_pisos'].isin(criterios_estado_piso)].index, inplace=True)

# %%
list(df_concatenado['calidad_acabados_pisos'].unique())
# Out:
# ['Normal',
#  'Lujoso',
#  'Sin Acabados',
#  'Sencillo',
#  'Bueno',
#  '0',
#  '"dependencias de buen tamaño y distribución, estado de conservación aceptable la habitación del primer piso fue hecha recientemente con divisiones en driwall. "',
#  'y en 3 piso un apartamento con sala, comedor, cocina, ropas, baño y 2 alcobas."',
#  '"Buena distribución de las dependencias. "',
#  '"Las dependencias se encuentran en buen estado al momento de la visita"',
#  '"Buena distribución de las dependencias."',
#  '"El inmueble tiene una buena distribución interior , con buena iluminación y ventilación."',
#  'tercer piso, aún no se puede preci"',
#  '"Se observa con buena distribución todos los espacios."',
#  'Piso 3: Alcoba con baño privado y terraza. Las dependencias cuenta con buena iluminación  ventilación natural. "',
#  '"Sala comedor, balcón, cocina tipo americano, cuarto de ropas con lavadero, baño social, dos habitaciones, una es la principal con baño privado. Piso en Porcelanato. Construcción Bloque H5. Vivienda Nueva, excelentes acabados y enlucimiento."',
#  '"el edificio cuenta con zona de lavandería, por tal motivo, no tiene zona de ropas en el apartamento. "',
#  '"Son acordes a las necesidades que presentan las personas que habitan el inmueble y demuestra el pleno aprovechamiento de los espacios que pertenecen al mismo."',
#  '"Tiene: cocina, zona de oficios, sala, comedor, baño social, estudio y 3 alcobas."',
#  'Baño social, zona de ropas con lavadero cubierta. Se observa buena estructura, enlucimiento y acabados."',
#  'Regular',
#  '"El apartamento consta de sala comedor, cocina, baño, zona de ropas y tres alcobas, una de ellas con baño privado  El apartamento cuenta con buena distribución interna en su proporción frente- fondo."',
#  'Sin acabados',
#  'Una alcoba."',
#  '"Inmueble de 2 pisos y terraza cubierta. En piso 1: sala comedor, cocina, baño social, patio interno área estudio. Piso 2: alcoba principal con baño, 2 alcobas, hall. Terraza: área terraza patio de ropas, zona de oficios."',
#  '"Espacios poco ventilados e iluminados."',
#  '"El apartamento es de 3 alcobas con closet, la principal con baño. Tiene dos balcones, en la zona social y en la alcoba principal. Sus espacios son de buen diseño, con buena iluminación natural y tiene muy buena vista. "',
#  '"dependencia con excelente luminosidad y en buen estado al momento de realizar la visita"',
#  '"amplias con suficiente iluminación natural"',
#  '1',
#  '"Predio no cuenta con construcción"',
#  '"Se puede adelantar vivienda en dos pisos y terraza"',
#  '"El lote valorado no cuenta con construcciones"',
#  '"Sala comedor, balcón, cocina con zona ropas, 3 alcobas, baño múltiple social. Cocina sencilla con mesón en mármol y estufa, con enchapes',
#  'Apto 2: Sala-comedor, dos alcobas, cocina y baño. Terraza. "']

# %%
criterios_acabados_piso = ['Normal', 'Lujoso', 'Sin Acabados', 'Sencillo', 'Bueno', 'Regular', 'Sin acabados']
train_data.drop(train_data[~train_data['calidad_acabados_pisos'].isin(criterios_acabados_piso)].index, inplace=True)
test_data.drop(test_data[~test_data['calidad_acabados_pisos'].isin(criterios_acabados_piso)].index, inplace=True)

train_data['calidad_acabados_pisos'] = train_data['calidad_acabados_pisos'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_pisos'] = test_data['calidad_acabados_pisos'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['estado_acabados_muros'].unique())
# Out:
# ['Bueno',
#  'Sin acabados',
#  'Regular',
#  'Normal',
#  'Sencillo',
#  '0',
#  'Dependencias estrechas por su forma alargada pero bien iluminadas por la serie de vacíos que tiene.',
#  'Lujoso',
#  'Malo',
#  '"El inmueble cuenta con buena distribución espacial."',
#  '"El apartamento 307, consta de: sala, comedor, balcón, cocina, zona de oficios, estar, baño social, alcoba auxiliar y alcoba  principal con baño privado. "',
#  '"El inmueble tasado corresponde a una casa tipo VIS, medianera, de 2 pisos, estrato 2. Adecuada distribución: 1er piso con: jardín con garaje, sala comedor, cocina, patio ropas, baño y 1 alcoba',
#  '"Buena distribución de las dependencias. "',
#  '"El apartamento 304 del edificio 4, consta de: sala, comedor, balcón, cocina, zona de oficios, estudio, baño social, 2 alcobas auxiliares y alcoba principal con baño privado y vestier"',
#  '"Bien inmueble con una adecuada distribución."',
#  'Sin Acabados',
#  '"Las dependencias de la vivienda cuentas con unas áreas producto de dimensiones aptas para su buen funcionamiento."',
#  '"Espacios funcionales, ventilados e iluminados."',
#  '"El apartamento 204 del bloque F, consta de: sala, comedor, cocina, zona de oficios, estudio, baño social,  2 alcobas auxiliares y alcoba  principal con baño privado y terraza. La terraza es común de uso exclusivo con 1,21 m2. "',
#  'pisos en cemento rustico, baño con enchapes en piso y pared, independientes ducha y sanitario."']

# %%
criterios_acabados_muros = ['Bueno', 'Sin acabados', 'Regular', 'Normal', 'Sencillo','Lujoso', 'Malo', 'Sin Acabados']
train_data.drop(train_data[~train_data['estado_acabados_muros'].isin(criterios_acabados_muros)].index, inplace=True)
test_data.drop(test_data[~test_data['estado_acabados_muros'].isin(criterios_acabados_muros)].index, inplace=True)

train_data['estado_acabados_muros'] = train_data['estado_acabados_muros'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_muros'] = test_data['estado_acabados_muros'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['calidad_acabados_muros'].unique())
# Out:
# ['Normal',
#  'Sin Acabados',
#  'Lujoso',
#  'Sencillo',
#  'Bueno',
#  '"Solo el baño social se entrega con aparatos instalados"',
#  '0',
#  '2do piso comprende: 2 alcobas, hall y baño de alcobas."',
#  'Regular',
#  'Sin acabados']

# %%
criterios_calidad_muros = ['Normal', 'Sin acabados', 'Lujoso', 'Sencillo', 'Bueno','Regular', 'Sin Acabados']
train_data.drop(train_data[~train_data['calidad_acabados_muros'].isin(criterios_calidad_muros)].index, inplace=True)
test_data.drop(test_data[~test_data['calidad_acabados_muros'].isin(criterios_calidad_muros)].index, inplace=True)

train_data['calidad_acabados_muros'] = train_data['calidad_acabados_muros'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_muros'] = test_data['calidad_acabados_muros'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['estado_acabados_techos'].unique())
# Out:
# ['Bueno',
#  'Sin acabados',
#  'Regular',
#  'Malo',
#  'Normal',
#  'Sencillo',
#  '"Ante jardín sin cerramiento',
#  'Lujoso',
#  '0',
#  'Sin Acabados',
#  '"Buena distribución de las dependencias."']

# %%
criterios_estado_techos = ['Bueno', 'Sin acabados', 'Regular', 'Malo', 'Normal','Sencillo', 'Lujoso',  'Sin Acabados']
train_data.drop(train_data[~train_data['estado_acabados_techos'].isin(criterios_estado_techos)].index, inplace=True)
test_data.drop(test_data[~test_data['estado_acabados_techos'].isin(criterios_estado_techos)].index, inplace=True)

train_data['estado_acabados_techos'] = train_data['estado_acabados_techos'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_techos'] = test_data['estado_acabados_techos'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['calidad_acabados_techos'].unique())
# Out:
# ['Normal',
#  'Lujoso',
#  'Sin Acabados',
#  'Sencillo',
#  'Bueno',
#  'Sala comedor, cocina sencilla con mesón en concreto, baño social, dos habitaciones, patio de ropas con lavadero. "',
#  '"Dependencias amplias en sala, comedor, estudio y terrazas',
#  'Regular',
#  'Sin acabados',
#  '0']

# %%
criterios_calidad_techos = ['Normal', 'Lujoso', 'Sin Acabados', 'Sencillo', 'Bueno', 'Regular', 'Sin acabados']
train_data.drop(train_data[~train_data['calidad_acabados_techos'].isin(criterios_calidad_techos)].index, inplace=True)
test_data.drop(test_data[~test_data['calidad_acabados_techos'].isin(criterios_calidad_techos)].index, inplace=True)

train_data['calidad_acabados_techos'] = train_data['calidad_acabados_techos'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_techos'] = test_data['calidad_acabados_techos'].replace('Sin Acabados','Sin acabados')

# %%
df_concatenado['estado_acabados_madera'].unique()
# Out:
# array(['Bueno', 'Sin acabados', 'Regular', 'Normal', 'Sencillo', 'Malo',
#        'Lujoso',
#        'pero las habitaciones son muy estrechas o con dimensiones mal diseñadas que hacen que el inmueble no sea atractivo para vivir."',
#        'Sin Acabados',
#        '"Consta de: sala, comedor, balcón, cocina integral abierta con mezón tipo barra americana de Quarzón, dos alcobas auxiliares, baño social y alcoba principal con baño privado'],
#       dtype=object)

# %%
criterios_estado_madera = ['Bueno', 'Sin acabados', 'Regular', 'Normal', 'Sencillo', 'Malo', 'Lujoso', 'Sin Acabados']
train_data.drop(train_data[~train_data['estado_acabados_madera'].isin(criterios_estado_madera)].index, inplace=True)
test_data.drop(test_data[~test_data['estado_acabados_madera'].isin(criterios_estado_madera)].index, inplace=True)

train_data['estado_acabados_madera'] = train_data['estado_acabados_madera'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_madera'] = test_data['estado_acabados_madera'].replace('Sin Acabados','Sin acabados')

# %%
df_concatenado['calidad_acabados_madera'].unique()
# Out:
# array(['Normal', 'Sin Acabados', 'Lujoso', 'Sencillo', 'Bueno',
#        'Sin acabados', 'Malo', 'Regular', 'garaje cubierto."'],
#       dtype=object)

# %%
criterios_calidad_madera = ['Normal', 'Sin Acabados', 'Lujoso', 'Sencillo', 'Bueno', 'Sin acabados', 'Malo', 'Regular']
train_data.drop(train_data[~train_data['calidad_acabados_madera'].isin(criterios_calidad_madera)].index, inplace=True)
test_data.drop(test_data[~test_data['calidad_acabados_madera'].isin(criterios_calidad_madera)].index, inplace=True)

train_data['calidad_acabados_madera'] = train_data['calidad_acabados_madera'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_madera'] = test_data['calidad_acabados_madera'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['estado_acabados_metal'].unique())
# Out:
# ['Bueno',
#  'Sin acabados',
#  'Regular',
#  'Normal',
#  'Sencillo',
#  'Malo',
#  'Lujoso',
#  'Sin Acabados']

# %%
train_data['estado_acabados_metal'] = train_data['estado_acabados_metal'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_metal'] = test_data['estado_acabados_metal'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['calidad_acabados_metal'].unique())
# Out:
# ['Normal', 'Sencillo', 'Lujoso', 'Sin Acabados', 'Bueno', 'Regular']

# %%
train_data['calidad_acabados_metal'] = train_data['calidad_acabados_metal'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_metal'] = test_data['calidad_acabados_metal'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['estado_acabados_banos'].unique())
# Out:
# ['Bueno',
#  'Sin acabados',
#  'Regular',
#  'Normal',
#  'Sencillo',
#  'Malo',
#  'Lujoso',
#  'Sin Acabados']

# %%
train_data['estado_acabados_banos'] = train_data['estado_acabados_banos'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_banos'] = test_data['estado_acabados_banos'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['calidad_acabados_banos'].unique())
# Out:
# ['Normal', 'Lujoso', 'Sencillo', 'Sin Acabados', 'Bueno', 'Regular']

# %%
train_data['calidad_acabados_banos'] = train_data['calidad_acabados_banos'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_banos'] = test_data['calidad_acabados_banos'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['estado_acabados_cocina'].unique())
# Out:
# ['Bueno', 'Sin acabados', 'Regular', 'Normal', 'Sencillo', 'Malo', 'Lujoso']

# %%
train_data['estado_acabados_cocina'] = train_data['estado_acabados_cocina'].replace('Sin Acabados','Sin acabados')
test_data['estado_acabados_cocina'] = test_data['estado_acabados_cocina'].replace('Sin Acabados','Sin acabados')

# %%
list(df_concatenado['calidad_acabados_cocina'].unique())
# Out:
# ['Integral',
#  'Sencillo',
#  'Semi-Integral',
#  'Sin Acabados',
#  'Bueno',
#  'Normal',
#  'Regular',
#  'Lujoso']

# %%
train_data['calidad_acabados_cocina'] = train_data['calidad_acabados_cocina'].replace('Sin Acabados','Sin acabados')
test_data['calidad_acabados_cocina'] = test_data['calidad_acabados_cocina'].replace('Sin Acabados','Sin acabados')

# %%
# Continuamos con las columnas que son binarias (Si, No) para darles un formato único
diccionario_binarios = {'No':0, 'Si':1, '0':0, '1':1, 'No Aplica':0, 'Aplica':1}

# %%
columnas_binarias = ['sometido_a_propiedad_horizontal','antejardin','alcantarillado_en_el_predio' ,
'acueducto_en_el_predio' ,
'gas_en_el_predio' ,
'energia_en_el_predio' ,
'telefono_en_el_predio' ,
'predio_subdividido_fisicamente' ,
'rph' ,
'porteria' ,
'citofono' ,
'bicicletero' ,
'piscina' ,
'tanque_de_agua' ,
'club_house' ,
'garaje_visitantes' ,
'teatrino' ,
'sauna' ,
'vigilancia_privada' ,
'administracion' ,
'garaje_doble_1' ,
'garaje_paralelo_1' ,
'garaje_servidumbre_1' ,
'garaje_cubierto_2' ,
'garaje_doble_2' ,
'garaje_paralelo_2' ,
'garaje_servidumbre_2' ,
'garaje_cubierto_3' ,
'garaje_doble_3' ,
'garaje_paralelo_3' ,
'garaje_servidumbre_3' ,
'garaje_cubierto_4' ,
'garaje_doble_4' ,
'garaje_servidumbre_4' ,
'garaje_cubierto_5' ,
'area_libre' ,
'barrio_legal',
'alcantarillado_en_el_sector',
'acueducto_en_el_sector',
'gas_en_el_sector',
'energia_en_el_sector',
'telefono_en_el_sector',
'vias_pavimentadas',
'sardineles_en_las_vias',
'andenes_en_las_vias',
'paradero',
'alumbrado',
'arborizacion',
'alamedas',
'ciclo_rutas']

for columna in columnas_binarias:
    train_data[columna] = train_data[columna].replace(diccionario_binarios)
    test_data[columna] = test_data[columna].replace(diccionario_binarios)

# %%
df_concatenado['garaje_cubierto_1'].unique()
# Out:
# array(['0', 'Si', 'No', '370-926861', '370-80382', '50N-20030335',
#        'Sencillo', '1', '001-903669', '018 - 140475', '040 - 537432',
#        '370-780052', '38', '67', '2', '370-330832', '43044', '001-842004',
#        'E-203', '060-233963', 'Malo', '001-1053647', '12905',
#        '50N-941945', '50C-1731779', '001-547629', '161', '240-269872',
#        '28', '001-1115065', '001-625912', '001-806034', '50C-1127807',
#        'No Tiene', '216', 'Normal', '370-955576', '060-88779'],
#       dtype=object)

# %%
train_data.drop(train_data[train_data['garaje_cubierto_1'] == '50C-1731779'].index, inplace=True)
test_data.drop(test_data[test_data['garaje_cubierto_1'] == '50C-1731779'].index, inplace=True)

train_data['garaje_cubierto_1'] = train_data['garaje_cubierto_1'].replace(diccionario_binarios)
test_data['garaje_cubierto_1'] = test_data['garaje_cubierto_1'].replace(diccionario_binarios)

# %%
df_concatenado['tipo_vigilancia'].unique()
# Out:
# array(['0', '24 Horas', '12 Horas', 'No', 'Si'], dtype=object)

# %%
diccionario_vigilancia={'24 Horas':1,'0':0,'12 Horas':1}
train_data['tipo_vigilancia'] = train_data['tipo_vigilancia'].replace(diccionario_vigilancia)
test_data['tipo_vigilancia'] = test_data['tipo_vigilancia'].replace(diccionario_vigilancia)

# %%
columnas_con_cero = ['proposito', 'tipo_credito', 'tipo_inmueble', 'motivo', 'uso_actual', 'tipo_deposito']

for columna in columnas_con_cero:
    train_data.drop(train_data[train_data[columna] == '0'].index, inplace=True)
    test_data.drop(test_data[test_data[columna] == '0'].index, inplace=True)

# %%
columnas_no_disponible = ['danos_previos', 'irregularidad_altura', 'irregularidad_planta', 'ajustes_sismoresistentes', 'estructura_reforzada']

for columna in columnas_no_disponible:
    train_data.drop(train_data[train_data[columna] == 'No disponible'].index, inplace=True)
    test_data.drop(test_data[test_data[columna] == 'No disponible'].index, inplace=True)

# %%
diccionario_danos = {'Con daños previos':1,'Sin daños previos':0}
train_data['danos_previos'] = train_data['danos_previos'].replace(diccionario_danos)
test_data['danos_previos'] = test_data['danos_previos'].replace(diccionario_danos)

# %%
diccionario_ajustes = {'Reparados':1,'No Reparados':0}
train_data['ajustes_sismoresistentes'] = train_data['ajustes_sismoresistentes'].replace(diccionario_ajustes)
test_data['ajustes_sismoresistentes'] = test_data['ajustes_sismoresistentes'].replace(diccionario_ajustes)

# %%
diccionario_irregularidad = {'Sin irregularidad':0, 'Con irregularidad':1}
columnas_irregularidad = ['irregularidad_planta', 'irregularidad_altura']

for columna in columnas_irregularidad:
    train_data[columna] = train_data[columna].replace(diccionario_irregularidad)
    test_data[columna] = test_data[columna].replace(diccionario_irregularidad)

# %%
df_concatenado = pd.concat([train_data, test_data], ignore_index=True)

valores_unicos_por_columna = {}

for columna in df_concatenado.columns:
    valores_unicos_por_columna[columna] = df_concatenado[columna].unique()

# Imprimir los valores únicos por columna
for columna, valores_unicos in valores_unicos_por_columna.items():
    print(f'Valores únicos en la columna "{columna}":')
    print(valores_unicos)
    print('\n')
# Out:
# Valores únicos en la columna "id":
# ['9101' '6770' '3343' '8209' '5874' '2054' '8568' '3525' '2051' '9652'
#  '4793' '7495' '828' '4230' '1029' '8704' '4224' '2909' '7074' '11143'
#  '3703' '5411' '630' '13819' '4365' '11900' '4964' '5199' '3560' '1560'
#  '6894' '4125' '4194' '4557' '3174' '694' '5621' '1057' '6233' '6247'
#  '8489' '8470' '6406' '8360' '4243' '1952' '5522' '3361' '7117' '708'
#  '8452' '4562' '4566' '1961' '4619' '4653' '8603' '3004' '3753' '2114'
#  '486' '1941' '2459' '10073' '6358' '15057' '4632' '2432' '11519' '12863'
#  '4659' '16702' '6070' '4925' '5167' '12269' '3913' '5005' '6140' '175'
#  '4906' '3900' '4011' '4941' '4277' '2988' '4936' '5730' '1387' 3961 6780
#  4094 549]
#
#
# Valores únicos en la columna "objeto":
# ['Originación' 'Remate']
#
#
# Valores únicos en la columna "motivo":
# ['Leasing Habitacional' 'Crédito hipotecario de vivienda'
#  'Compra de cartera' 'Garantía' 'Remates' 'Actualización de garantías'
#  'Empleados' 'Dación en Pago']
#
#
# Valores únicos en la columna "proposito":
# ['Garantía Hipotecaria' 'Transacción Comercial de Venta']
#
#
# Valores únicos en la columna "tipo_avaluo":
# ['Hipotecario' 'Remates']
#
#
# Valores únicos en la columna "tipo_credito":
# ['Vivienda' 'Diferente de Vivienda']
#
#
# Valores únicos en la columna "tipo_subsidio":
# [nan]
#
#
# Valores únicos en la columna "departamento_inmueble":
# ['BOGOTÁ, D. C.' 'ANTIOQUIA' 'BOLÍVAR' 'BOYACÁ' 'TOLIMA' 'CUNDINAMARCA'
#  'CALDAS' 'QUINDÍO' 'META' 'SANTANDER']
#
#
# Valores únicos en la columna "municipio_inmueble":
# ['BOGOTÁ, D. C.' 'SABANETA' 'CARTAGENA' 'SOGAMOSO' 'MEDELLIN' 'MELGAR'
#  'SOPO' 'MANIZALES' 'CHIA' 'DUITAMA' 'CHIQUINQUIRA' 'LA CEJA' 'LA DORADA'
#  'ITAGUI' 'COTA' 'ANAPOIMA' 'CAJICA' 'LA MESA' 'ARMENIA' 'VILLAVICENCIO'
#  'ZIPAQUIRA' 'RIONEGRO' 'BUCARAMANGA' 'PACHO']
#
#
# Valores únicos en la columna "sector":
# ['Urbano' 'Rural']
#
#
# Valores únicos en la columna "alcantarillado_en_el_sector":
# [1]
#
#
# Valores únicos en la columna "acueducto_en_el_sector":
# [1]
#
#
# Valores únicos en la columna "gas_en_el_sector":
# [1]
#
#
# Valores únicos en la columna "energia_en_el_sector":
# [1]
#
#
# Valores únicos en la columna "telefono_en_el_sector":
# [1 0]
#
#
# Valores únicos en la columna "vias_pavimentadas":
# [1]
#
#
# Valores únicos en la columna "sardineles_en_las_vias":
# [1 0]
#
#
# Valores únicos en la columna "andenes_en_las_vias":
# [1 0]
#
#
# Valores únicos en la columna "estrato":
# ['4' '6' '3' '5' '2']
#
#
# Valores únicos en la columna "barrio_legal":
# [1 0]
#
#
# Valores únicos en la columna "topografia_sector":
# ['Plano' 'Ligera' 'Inclinado']
#
#
# Valores únicos en la columna "condiciones_salubridad":
# ['Buenas']
#
#
# Valores únicos en la columna "transporte":
# ['Bueno' 'Regular']
#
#
# Valores únicos en la columna "demanda_interes":
# ['Media' 'Fuerte' 'Nula']
#
#
# Valores únicos en la columna "paradero":
# [1 0]
#
#
# Valores únicos en la columna "alumbrado":
# [1 0]
#
#
# Valores únicos en la columna "arborizacion":
# [1 0]
#
#
# Valores únicos en la columna "alamedas":
# [1 0]
#
#
# Valores únicos en la columna "ciclo_rutas":
# [1 0]
#
#
# Valores únicos en la columna "nivel_equipamiento_comercial":
# ['Bueno' 'Muy bueno' 'Regular Malo']
#
#
# Valores únicos en la columna "alcantarillado_en_el_predio":
# [1 0]
#
#
# Valores únicos en la columna "acueducto_en_el_predio":
# [1 0]
#
#
# Valores únicos en la columna "gas_en_el_predio":
# [1 0]
#
#
# Valores únicos en la columna "energia_en_el_predio":
# [1 0]
#
#
# Valores únicos en la columna "telefono_en_el_predio":
# [1 0]
#
#
# Valores únicos en la columna "tipo_inmueble":
# ['Apartamento' 'Casa' 'Casa Rural']
#
#
# Valores únicos en la columna "uso_actual":
# ['Vivienda' 'Sin uso - Vivienda']
#
#
# Valores únicos en la columna "clase_inmueble":
# ['Multifamiliar' 'Unifamiliar' 'Bifamiliar']
#
#
# Valores únicos en la columna "sometido_a_propiedad_horizontal":
# [1 0]
#
#
# Valores únicos en la columna "antejardin":
# [1 0]
#
#
# Valores únicos en la columna "predio_subdividido_fisicamente":
# [0]
#
#
# Valores únicos en la columna "contadores_agua":
# ['0' 0]
#
#
# Valores únicos en la columna "contadores_luz":
# ['0' 0]
#
#
# Valores únicos en la columna "accesorios":
# ['0' 0]
#
#
# Valores únicos en la columna "area_valorada":
# ['91.85' '193.2' '58,3' '75.53' '59,75' '151,58' '224' '81,13' '65,33'
#  '92.2' '51,67' '110.08' '75,3' '75,96' '97,29' '105.26' '34,66' '49,66'
#  '57.98' '89.24' '50,64' '50,26' '247,23' '89' '78,59'
#  '71.691999999999993' '205,02' '139,04' '89,28' '83' '102.6' '101,85'
#  '95,32' '65,1' '254' '72,8' '80,25' '64,94' '58.18' '106.86' '104.37'
#  '87.212000000000003' '74.84' '110,95' '51,87' '108,3' '376582' '76.91'
#  '82,2' '55.23' '87,57' '46,04' '59,36' '93,43' '51,48' '98' '152,89'
#  '86,33' '66,16' '183,54' '84,98' '58,88' '189.13' '55.74' '40.39' '75,16'
#  '82,23' '114.99' '106.91' '118,09' '78.31' '70.59' '145,3' '96,21'
#  '53.91' '104,8' '92,21' '181.12' '110,19' '69,69' '148,49' '100,78'
#  '237,95' '49662' '56,6' '85,59' '93,85' '64,41' '106' '75.16' '92,05'
#  '282,44']
#
#
# Valores únicos en la columna "numero_piso":
# ['1' '5' '30' '4' '20' '17' '14' '2' '11' '6' '7' '3' '15' '9' '8' '13'
#  '10' '24' '25' '12' '16' 5 2 0]
#
#
# Valores únicos en la columna "numero_de_edificios":
# ['6' '1' '7' '4' '2' '3' '5' '12' '23' '10' '8' '35' '13' '44' '9' 2 3 6 0]
#
#
# Valores únicos en la columna "rph":
# [1 0]
#
#
# Valores únicos en la columna "porteria":
# [1 0]
#
#
# Valores únicos en la columna "citofono":
# [1 0]
#
#
# Valores únicos en la columna "bicicletero":
# [1 0]
#
#
# Valores únicos en la columna "piscina":
# [0 1]
#
#
# Valores únicos en la columna "tanque_de_agua":
# [1 0]
#
#
# Valores únicos en la columna "club_house":
# [0 1]
#
#
# Valores únicos en la columna "garaje_visitantes":
# [1 0]
#
#
# Valores únicos en la columna "teatrino":
# [0 1]
#
#
# Valores únicos en la columna "sauna":
# [0 1]
#
#
# Valores únicos en la columna "vigilancia_privada":
# [1 0]
#
#
# Valores únicos en la columna "tipo_vigilancia":
# [1 0]
#
#
# Valores únicos en la columna "administracion":
# [1 0]
#
#
# Valores únicos en la columna "vetustez":
# ['39' '7' '5' '0' '3' '11' '4' '12' '6' '8' '15' '1' '2' '13' '28' '9'
#  '32' '29' '36' '27' '25' '26' '10' 0 4 18]
#
#
# Valores únicos en la columna "pisos_bodega":
# ['1' '2' '0' 2 1]
#
#
# Valores únicos en la columna "estructura":
# ['Mamposteria Estructural' 'Industrializada' 'Tradicional' 'Muro de carga']
#
#
# Valores únicos en la columna "ajustes_sismoresistentes":
# [0 1]
#
#
# Valores únicos en la columna "cubierta":
# ['Placa concreto imp.' 'Teja fibrocemento' 'Teja de barro' 'Otros']
#
#
# Valores únicos en la columna "fachada":
# ['Ladrillo a la vista' 'Pañete y pintura' 'Graniplast' 'Otros']
#
#
# Valores únicos en la columna "tipo_fachada":
# ['Mayor a 6 metros' 'De 3 a 6 metros' 'De 0 a 3 metros']
#
#
# Valores únicos en la columna "estructura_reforzada":
# ['Trabes coladas en sitio' 'No tiene trabes']
#
#
# Valores únicos en la columna "danos_previos":
# [0]
#
#
# Valores únicos en la columna "material_de_construccion":
# ['Mampostería' 'Concreto Reforzado' 'Mixtas u Otro']
#
#
# Valores únicos en la columna "iluminacion":
# ['Bueno']
#
#
# Valores únicos en la columna "ventilacion":
# ['Bueno']
#
#
# Valores únicos en la columna "irregularidad_planta":
# [0]
#
#
# Valores únicos en la columna "irregularidad_altura":
# [0 1]
#
#
# Valores únicos en la columna "habitaciones":
# ['3' '2' '1' '0' '4' 3 7]
#
#
# Valores únicos en la columna "estar_habitacion":
# ['0' '1' '2' 0 1]
#
#
# Valores únicos en la columna "cuarto_servicio":
# ['0' '1' 0 1]
#
#
# Valores únicos en la columna "closet":
# ['3' '2' '1' '0' '4' 3 5 7]
#
#
# Valores únicos en la columna "sala":
# ['1' 1]
#
#
# Valores únicos en la columna "comedor":
# ['1' '0' 1]
#
#
# Valores únicos en la columna "bano_privado":
# ['1' '3' '2' '0' '4' 1 7]
#
#
# Valores únicos en la columna "bano_social":
# ['1' '2' '0' '14' 1]
#
#
# Valores únicos en la columna "bano_servicio":
# ['0' '1' 0 1]
#
#
# Valores únicos en la columna "cocina":
# ['1' '0' 1]
#
#
# Valores únicos en la columna "estudio":
# ['0' '1' 0 1]
#
#
# Valores únicos en la columna "balcon":
# ['0' '1' '2' '11' 1 0 7]
#
#
# Valores únicos en la columna "terraza":
# ['0' '1' '2' '3' 0 1]
#
#
# Valores únicos en la columna "patio_interior":
# ['0' '1' 0 1]
#
#
# Valores únicos en la columna "jardin":
# ['0' '1' 0]
#
#
# Valores únicos en la columna "zona_de_ropas":
# ['1' '0' 1]
#
#
# Valores únicos en la columna "zona_verde_privada":
# ['0' '1' 0]
#
#
# Valores únicos en la columna "local":
# ['0' 0]
#
#
# Valores únicos en la columna "oficina":
# ['0' 0]
#
#
# Valores únicos en la columna "bodega":
# ['0' '1' 0]
#
#
# Valores únicos en la columna "estado_acabados_pisos":
# ['Bueno' 'Sin acabados']
#
#
# Valores únicos en la columna "calidad_acabados_pisos":
# ['Normal' 'Lujoso' 'Sin acabados']
#
#
# Valores únicos en la columna "estado_acabados_muros":
# ['Bueno']
#
#
# Valores únicos en la columna "calidad_acabados_muros":
# ['Normal' 'Lujoso' 'Sencillo']
#
#
# Valores únicos en la columna "estado_acabados_techos":
# ['Bueno']
#
#
# Valores únicos en la columna "calidad_acabados_techos":
# ['Normal' 'Lujoso' 'Sencillo']
#
#
# Valores únicos en la columna "estado_acabados_madera":
# ['Bueno']
#
#
# Valores únicos en la columna "calidad_acabados_madera":
# ['Normal' 'Sencillo' 'Lujoso']
#
#
# Valores únicos en la columna "estado_acabados_metal":
# ['Bueno']
#
#
# Valores únicos en la columna "calidad_acabados_metal":
# ['Normal' 'Lujoso']
#
#
# Valores únicos en la columna "estado_acabados_banos":
# ['Bueno' 'Sin acabados']
#
#
# Valores únicos en la columna "calidad_acabados_banos":
# ['Normal' 'Lujoso' 'Sin acabados']
#
#
# Valores únicos en la columna "estado_acabados_cocina":
# ['Bueno' 'Sin acabados']
#
#
# Valores únicos en la columna "calidad_acabados_cocina":
# ['Integral' 'Semi-Integral' 'Sin acabados']
#
#
# Valores únicos en la columna "tipo_garaje":
# ['Exclusivo' 'Privado' 'No Tiene']
#
#
# Valores únicos en la columna "numero_total_de_garajes":
# ['1' '4' '2' '3' '0' 1 2]
#
#
# Valores únicos en la columna "total_cupos_parquedaro":
# ['1' '5' '2' '4' '3' '0' 1 2]
#
#
# Valores únicos en la columna "garaje_cubierto_1":
# [1 0]
#
#
# Valores únicos en la columna "garaje_doble_1":
# [0 1]
#
#
# Valores únicos en la columna "garaje_paralelo_1":
# [0]
#
#
# Valores únicos en la columna "garaje_servidumbre_1":
# [0 1]
#
#
# Valores únicos en la columna "garaje_cubierto_2":
# [0 1]
#
#
# Valores únicos en la columna "garaje_doble_2":
# [0 1]
#
#
# Valores únicos en la columna "garaje_paralelo_2":
# [0]
#
#
# Valores únicos en la columna "garaje_servidumbre_2":
# [0 1]
#
#
# Valores únicos en la columna "garaje_cubierto_3":
# [0 1]
#
#
# Valores únicos en la columna "garaje_doble_3":
# [0]
#
#
# Valores únicos en la columna "garaje_paralelo_3":
# [0]
#
#
# Valores únicos en la columna "garaje_servidumbre_3":
# [0]
#
#
# Valores únicos en la columna "garaje_cubierto_4":
# [0 1]
#
#
# Valores únicos en la columna "garaje_doble_4":
# [0]
#
#
# Valores únicos en la columna "garaje_servidumbre_4":
# [0]
#
#
# Valores únicos en la columna "garaje_cubierto_5":
# [0]
#
#
# Valores únicos en la columna "tipo_deposito":
# ['Exclusivo' 'Privado']
#
#
# Valores únicos en la columna "numero_total_depositos":
# ['1' '3' '2' 1 2]
#
#
# Valores únicos en la columna "area_privada":
# ['91.85' '180.66' '58,3' '75.53' '59,75' '151,58' '224' '81,13' '68,17'
#  '92.2' '51,67' '110.08' '75,3' '75,96' '97,29' '105.26' '34,66' '49,66'
#  '57.98' '89.24' '50,64' '50,26' '247,23' '89' '78,59' '61.79' '205,02'
#  '139,04' '89,28' '83' '102.6' '101,85' '95,32' '65,1' '254' '72,8'
#  '80,25' '64,94' '58.18' '106.86' '104.37' '87.21' '74.84' '110,95'
#  '51,87' '108,3' '896,58' '76.91' '82,2' '55.23' '87,57' '46,04' '59,36'
#  '93,43' '51,48' '98' '527,79' '86,33' '66,16' '181,37' '84,98' '58,88'
#  '109.8' '55.74' '40.39' '75,16' '82,23' '105.7' '106.91' '118,09' '78.31'
#  '70.59' '145,3' '96,21' '53.91' '104,8' '92,21' '181.12' '110,19' '69,69'
#  '148,49' '100,78' '245,88' '56,6' '85,59' '93,85' '64,41' '106' '75.16'
#  '85,97' '0']
#
#
# Valores únicos en la columna "valor_area_privada":
# ['393118000' '1228488000' '169070000,0' '496987400' '370450000,00'
#  '757900000,00' '1603840000' '165099550,00' '212350600,00' '436567000'
#  '192729100,00' '473344000' '263550000,0' '300042000,00' '285546150,00'
#  '585098236' '275547000,00' '173810000,00' '303235400' '384624400'
#  '136728000,00' '301560000,00' '484570800,00' '240300000' '251488000,00'
#  '101953500' '1194241500,00' '834240000,00' '495057600,00' '266845000'
#  '92340000' '478695000,00' '514728000,00' '201810000,0' '508000000'
#  '189280000,0' '312172500,00' '199885320,00' '329880600' '534300000'
#  '584472000' '383732000' '401166000' '303139420' '521465000,00'
#  '306033000,00' '826329000,0' '1234180500,00' '344787530' '312360000,0'
#  '231966000' '216297900,00' '170101686,00' '187577600,00' '291968750,00'
#  '113256000,00' '303800000' '822867700,00' '297838500,00' '211712000,00'
#  '870576000,00' '309760598,00' '197248000,00' '411750000' '326079000'
#  '214268950' '559942000,00' '222021000,00' '531353900' '534550000'
#  '897484000,00' '358659800' '310596000' '1520564500,0' '538776000,00'
#  '176609160' '408720000,0' '375294700,00' '860320000' '325060500,00'
#  '320574000,00' '1023096100,00' '463588000,00' '770956000,00'
#  '213538000,00' '149820200,0' '436509000,00' '287181000,00' '238317000,00'
#  180200000 375800000 272524900 0]
#
#
# Valores únicos en la columna "area_garaje":
# ['0' '13,55' '19,8' '28.8' '10,38' '11,5' '14,47' '12,07' '10,57' '10,94'
#  '2' '24,02' '14.48' '34,16' '37,5' '30,15' '15.26' '20,47' '13' '10,8'
#  '23,83' '11,04' '9.9' '36.35' '1' '23.91' '10,85' '10.199999999999999'
#  '10,84' '15,21' '12' '26.065999999999999' '23,50' '23,0' '11.01' '10.59'
#  '10.5' '40,78' '24,31' '23,17' '12,95' '10,13' '11,25' '15,1' '11.37'
#  '14,51']
#
#
# Valores únicos en la columna "valor_area_garaje":
# ['0' '16000000' '38000000' '50025600' '12000000' '18000000' '14222000,00'
#  '36000000' '28824000,00' '10136000' '85400000,00' '48000000' '40000000'
#  '14950000,0' '15000000' '17000000' '50000000' '20000000' '28000000'
#  '19000000' '35000000' '28200000,00' '44000000' '13800000,0' '59400000,0'
#  '60000000' '43758000,00' '32000000' '19425000,00' '46000000,0' 15500000
#  21000000 20000000 0]
#
#
# Valores únicos en la columna "area_deposito":
# ['0' '2,15' '2,19' '2,5' '2,87' '4,18' '1,43' '6,5' '4,07' '0.98' '4,51'
#  '1,8' '2,2' '2,85' '1,6' '1.29' '5.2' '1' '2.25' '3.64' '2,54' '5,17'
#  '2,71' '1,13' '4.25' '4,35' '3,31' '0.52' '2.4' '5,32' '2,55' '5,56'
#  '2,44' '2,8' '1.96' '4,5']
#
#
# Valores únicos en la columna "valor_area_deposito":
# ['0' '3000000' '2000000' '3000000,0' '4000000' '3500000' '9750000,0'
#  '4884000,00' '2156000' '2880000,0' '1500000' '5000000' '6000000'
#  '10000000' '2500000' '1130000,00' '7000000' '1356000,00' '4491000,00' 0
#  4000000 5000000]
#
#
# Valores únicos en la columna "area_terreno":
# ['0' '120']
#
#
# Valores únicos en la columna "valor_area_terreno":
# ['0' '78000000']
#
#
# Valores únicos en la columna "area_construccion":
# ['0' '282,44']
#
#
# Valores únicos en la columna "valor_area_construccion":
# ['0' 0 355874400]
#
#
# Valores únicos en la columna "area_otros":
# ['0' '2315,85' '1007,37' '2,17']
#
#
# Valores únicos en la columna "valor_area_otros":
# ['0' '509487000,00' '594348300,00' '8246000,00' 0]
#
#
# Valores únicos en la columna "area_libre":
# [0 1]
#
#
# Valores únicos en la columna "valor_area_libre":
# ['0' '48875000' '2070000,0' '29400000' '6345000,00' '3877500,00'
#  '5940000,0' '14009320' '2508000' '92599000,00' '6990000,00' '38779000'
#  '57033100,00' 0 5850000]
#
#
# Valores únicos en la columna "valor_total_avaluo":
# ['393118000' '1277363000' '190140000,0' '496987400' '408450000,00'
#  '757900000,00' '1683265600' '179099550,00' '233350600,00' '436567000'
#  '211729100,00' '473344000' '263550000,0' '322042000,00' '305046150,00'
#  '585098236' '275547000,00' '180155000,00' '303235400' '384624400'
#  '160700000,00' '301560000,00' '994057800,00' '276300000' '285196000,00'
#  '114245500' '1279641500,00' '882240000,00' '539057600,00' '284675000,0'
#  '107340000' '478695000,00' '550728000,00' '221810000,0' '1102348300,00'
#  '206780000,0' '362172500,00' '219885320,00' '352880600' '534300000'
#  '584472000' '383732000' '444166000' '303139420' '521465000,00'
#  '332033000,00' '826329000,0' '1234180500,00' '376787530' '328360000,0'
#  '260966000' '233797900,00' '191101686,00' '187577600,00' '315846250,00'
#  '114386000,00' '345800000' '822867700,00' '326038500,00' '234712000,00'
#  '927822000,00' '315700598,00' '197248000,00' '411750000' '348579000'
#  '231268950' '559942000,00' '237177000,00' '545363220' '534550000'
#  '897484000,00' '358659800' '313104000' '1613163500,00' '598176000,00'
#  '195109160' '468720000,0' '426042700,00' '899099000' '362060500,00'
#  '344490000,00' '1080129200,00' '519588000,00' '770956000,00'
#  '213538000,00' '149820200,0' '456509000,00' '309181000,00' '261317000,00'
#  nan]
#
#
# Valores únicos en la columna "Longitud":
# ['-74.08018' '-74.0529933' '0.0' '-74.04942' '-75.5520741' '-74.05024'
#  '-74.6104578' '-74.0469062' '-75.847829' '-75.4563265' '-73.0323538'
#  '-73.8159016' '-76.3161654' '-73.6536787' '-74.130406' '-74.03209'
#  '-75.4565268' '-74.149144' '-74.05701' '-76.5829689' '-74.0588651'
#  '-75.6544228' '-74.0257306' '-75.5497037' '-74.06102' '-73.6332512'
#  '-75.5192204' '-74.08172' '-75.6206277' '-74.1359294' '-75.6004622'
#  '-757.358.007']
#
#
# Valores únicos en la columna "Latitud":
# ['4.647409' '4.6785528' '0.0' '4.708311' '10.4045076' '4.703234'
#  '10.4637422' '4.7159836' '4.9956855' '10.5330051' '5.8356275' '5.6103316'
#  '3.6905785' '4.1016993' '4.6718896' '4.707082' '10.532398' '4.6198904'
#  '4.700294' '2.4840694' '4.7441375' '4.5468471' '4.9087791' '6.3372514'
#  '4.639595' '4.1306107' '10.4467565' '4.696368' '6.152234' '4.7245765'
#  '6.2709418' '47.023.801']

# %%
columnas_numericas = ['accesorios',
'acueducto_en_el_predio',
'acueducto_en_el_sector',
'administracion',
'ajustes_sismoresistentes',
'alamedas',
'alcantarillado_en_el_predio',
'alcantarillado_en_el_sector',
'alumbrado',
'andenes_en_las_vias',
'antejardin',
'arborizacion',
'area_construccion',
'area_deposito',
'area_garaje',
'area_libre',
'area_otros',
'area_privada',
'area_terreno',
'area_valorada',
'balcon',
'bano_privado',
'bano_servicio',
'bano_social',
'barrio_legal',
'bicicletero',
'bodega',
'ciclo_rutas',
'citofono',
'closet',
'club_house',
'cocina',
'comedor',
'contadores_agua',
'contadores_luz',
'cuarto_servicio',
'danos_previos',
'energia_en_el_predio',
'energia_en_el_sector',
'estar_habitacion',
'estudio',
'garaje_cubierto_1',
'garaje_cubierto_2',
'garaje_cubierto_3',
'garaje_cubierto_4',
'garaje_cubierto_5',
'garaje_doble_1',
'garaje_doble_2',
'garaje_doble_3',
'garaje_doble_4',
'garaje_paralelo_1',
'garaje_paralelo_2',
'garaje_paralelo_3',
'garaje_servidumbre_1',
'garaje_servidumbre_2',
'garaje_servidumbre_3',
'garaje_servidumbre_4',
'garaje_visitantes',
'gas_en_el_predio',
'gas_en_el_sector',
'habitaciones',
'id',
'indice_ocupacion',
'irregularidad_altura',
'irregularidad_planta',
'jardin',
'Latitud',
'local',
'Longitud',
'numero_de_edificios',
'numero_piso',
'numero_total_de_garajes',
'numero_total_depositos',
'oficina',
'paradero',
'patio_interior',
'piscina',
'pisos_bodega',
'porteria',
'predio_subdividido_fisicamente',
'rph',
'sala',
'sardineles_en_las_vias',
'sauna',
'sometido_a_propiedad_horizontal',
'tanque_de_agua',
'teatrino',
'telefono_en_el_predio',
'telefono_en_el_sector',
'terraza',
'tipo_vigilancia',
'total_cupos_parquedaro',
'valor_area_construccion',
'valor_area_deposito',
'valor_area_garaje',
'valor_area_libre',
'valor_area_otros',
'valor_area_privada',
'valor_area_terreno',
'valor_total_avaluo',
'vetustez',
'vias_pavimentadas',
'vigilancia_privada',
'zona_de_ropas',
'zona_verde_privada',
]

for columna in columnas_numericas:
    if columna in train_data.columns:
        train_data[columna]=train_data[columna].apply(pd.to_numeric, errors='coerce')
    if columna in test_data.columns:
        test_data[columna]=test_data[columna].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# **Definir tipo de variables**

# %%
def clasificar_caracteristicas(dataframe, lista_categoricas, lista_numericas, umbral_unicos):
    if not lista_categoricas or not lista_numericas:
        raise ValueError("Las listas de características categóricas y numéricas no deben estar vacías.")

    caracteristicas_categoricas = []
    caracteristicas_numericas = []

    for columna in dataframe.columns:
        if columna not in ['valor_total_avaluo', 'id']:
            if (len(dataframe[columna].unique()) <= umbral_unicos or columna in lista_categoricas) and columna not in lista_numericas:
                caracteristicas_categoricas.append(columna)
            elif (len(dataframe[columna].unique()) > umbral_unicos or columna in lista_numericas) and columna not in lista_categoricas:
                caracteristicas_numericas.append(columna)

    return caracteristicas_categoricas, caracteristicas_numericas

# %%
carac_categoricas = [
    'departamento_inmueble', 'municipio_inmueble'
]
carac_numericas = [
    'habitaciones', 'closet', 'bano_privado', 'sala', 'comedor', 'bano_social', 'cocina', 'zona_de_ropas', 'contadores_agua', 'accesorios',
    'patio_interior', 'contadores_luz', 'balcon', 'terraza', 'oficina', 'total_cupos_parquedaro', 'estrato', 'bano_servicio', 'numero_total_de_garajes',
    'local', 'estar_habitacion', 'jardin', 'numero_total_depositos', 'cuarto_servicio', 'pisos_bodega', 'bodega'
]
threshold_unique = 40

caracteristicas_categoricas, caracteristicas_numericas = clasificar_caracteristicas(train_data, carac_categoricas, carac_numericas, threshold_unique)

print("Características categóricas:")
print(caracteristicas_categoricas)

print("\nCaracterísticas numéricas:")
print(caracteristicas_numericas)
# Out:
# Características categóricas:
# ['objeto', 'motivo', 'proposito', 'tipo_avaluo', 'tipo_credito', 'tipo_subsidio', 'departamento_inmueble', 'municipio_inmueble', 'sector', 'alcantarillado_en_el_sector', 'acueducto_en_el_sector', 'gas_en_el_sector', 'energia_en_el_sector', 'telefono_en_el_sector', 'vias_pavimentadas', 'sardineles_en_las_vias', 'andenes_en_las_vias', 'barrio_legal', 'topografia_sector', 'condiciones_salubridad', 'transporte', 'demanda_interes', 'paradero', 'alumbrado', 'arborizacion', 'alamedas', 'ciclo_rutas', 'nivel_equipamiento_comercial', 'alcantarillado_en_el_predio', 'acueducto_en_el_predio', 'gas_en_el_predio', 'energia_en_el_predio', 'telefono_en_el_predio', 'tipo_inmueble', 'uso_actual', 'clase_inmueble', 'sometido_a_propiedad_horizontal', 'antejardin', 'predio_subdividido_fisicamente', 'area_valorada', 'numero_piso', 'numero_de_edificios', 'rph', 'porteria', 'citofono', 'bicicletero', 'piscina', 'tanque_de_agua', 'club_house', 'garaje_visitantes', 'teatrino', 'sauna', 'vigilancia_privada', 'tipo_vigilancia', 'administracion', 'vetustez', 'estructura', 'ajustes_sismoresistentes', 'cubierta', 'fachada', 'tipo_fachada', 'estructura_reforzada', 'danos_previos', 'material_de_construccion', 'iluminacion', 'ventilacion', 'irregularidad_planta', 'irregularidad_altura', 'estudio', 'zona_verde_privada', 'estado_acabados_pisos', 'calidad_acabados_pisos', 'estado_acabados_muros', 'calidad_acabados_muros', 'estado_acabados_techos', 'calidad_acabados_techos', 'estado_acabados_madera', 'calidad_acabados_madera', 'estado_acabados_metal', 'calidad_acabados_metal', 'estado_acabados_banos', 'calidad_acabados_banos', 'estado_acabados_cocina', 'calidad_acabados_cocina', 'tipo_garaje', 'garaje_cubierto_1', 'garaje_doble_1', 'garaje_paralelo_1', 'garaje_servidumbre_1', 'garaje_cubierto_2', 'garaje_doble_2', 'garaje_paralelo_2', 'garaje_servidumbre_2', 'garaje_cubierto_3', 'garaje_doble_3', 'garaje_paralelo_3', 'garaje_servidumbre_3', 'garaje_cubierto_4', 'garaje_doble_4', 'garaje_servidumbre_4', 'garaje_cubierto_5', 'tipo_deposito', 'area_privada', 'valor_area_privada', 'area_garaje', 'valor_area_garaje', 'area_deposito', 'valor_area_deposito', 'area_terreno', 'valor_area_terreno', 'area_construccion', 'valor_area_construccion', 'area_otros', 'valor_area_otros', 'area_libre', 'valor_area_libre', 'Longitud', 'Latitud']
#
# Características numéricas:
# ['estrato', 'contadores_agua', 'contadores_luz', 'accesorios', 'pisos_bodega', 'habitaciones', 'estar_habitacion', 'cuarto_servicio', 'closet', 'sala', 'comedor', 'bano_privado', 'bano_social', 'bano_servicio', 'cocina', 'balcon', 'terraza', 'patio_interior', 'jardin', 'zona_de_ropas', 'local', 'oficina', 'bodega', 'numero_total_de_garajes', 'total_cupos_parquedaro', 'numero_total_depositos']

# %%
categorica = [x[0] for x in caracteristicas_categoricas]
numerica = [x[0] for x in caracteristicas_numericas]

# %%
for col in caracteristicas_numericas:
    try:
        # Intenta convertir directamente a float
        test_data[col] = test_data[col].astype(float)
        train_data[col] = train_data[col].astype(float)
    except KeyError as e:
        # Imprime información de depuración
        print(f"Error en la columna {col}: {e}")

        # En caso de error, reemplaza comas por puntos y convierte a float
        test_data[col] = test_data[col].str.replace(',', '.')
        test_data[col] = pd.to_numeric(test_data[col], errors='coerce').fillna(0).astype(float)

        train_data[col] = train_data[col].str.replace(',', '.')
        train_data[col] = pd.to_numeric(train_data[col], errors='coerce').fillna(0).astype(float)

# Convertir de nuevo a str después de la manipulación
for col in caracteristicas_numericas:
    test_data[col] = test_data[col].astype(str)

# %%
caracteristicas = [x for x in train_data.columns if x not in ['valor_total_avaluo', 'id']]

X_train, y_train = train_data[caracteristicas], train_data['valor_total_avaluo']
y_train = y_train.astype(float)

# %%
test_data['valor_total_avaluo'] = 0

X_test, y_test = test_data[caracteristicas], test_data['valor_total_avaluo']
y_test = pd.to_numeric(y_test, errors='coerce').fillna(0).astype(float)

# %%
# Create a pipeline for categorical features
categorical_pipeline = Pipeline([
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# Create a pipeline for numerical features
numerical_pipeline = Pipeline([
    ('scaler', StandardScaler())
])

# Use ColumnTransformer to apply the appropriate preprocessing for each feature type
preprocessor = ColumnTransformer([
    ('categorical', categorical_pipeline, caracteristicas_categoricas),
    ('numerical', numerical_pipeline, caracteristicas_numericas)
])

# Fit and transform the training data
X_train_enc = preprocessor.fit_transform(X_train)

# Transform the test data
X_test_enc = preprocessor.transform(X_test[caracteristicas])

# Obtener los nombres de las características
feature_names = preprocessor.get_feature_names_out()

# %%
# Eliminar filas con NaN en y_train
X_train = X_train[~y_train.isna()]
y_train = y_train.dropna()

# %%
# Eliminar filas con NaN en y_test
X_test = X_test[~y_test.isna()]
y_test = y_test.dropna()

# %%
# Ahora, realizar la búsqueda de hiperparámetros y evaluación del modelo
model_search_results = {}

# Perform random search for each model
for model_name, model in tqdm(models.items()):
    search = RandomizedSearchCV(model, param_distributions[model_name], n_iter=20,
                                scoring=make_scorer(mean_absolute_percentage_error, greater_is_better=False),
                                cv=5, n_jobs=-1, error_score='raise')

    try:
        search.fit(X_train_enc, y_train)

        # Evaluar en el conjunto de prueba después del ajuste
        y_pred = search.predict(X_test_enc)

        model_search_results[model_name] = {
            'best_params': search.best_params_,
            'test_MAPE': mean_absolute_percentage_error(y_test, y_pred),
            'model': search.best_estimator_  # Almacena el modelo ajustado
        }
    except Exception as e:
        print(f"Error during fitting {model_name}: {e}")
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 1059.27it/s]
# Error during fitting Linear Regression: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Ridge Regression: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Lasso Regression: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting ElasticNet Regression: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Decision Tree Regressor: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Random Forest Regressor: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Gradient Boosting Regressor: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting Support Vector Regressor: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting K-Nearest Neighbors Regressor: Found input variables with inconsistent numbers of samples: [89, 30]
# Error during fitting XGBoost Regressor: Found input variables with inconsistent numbers of samples: [89, 30]

# %%
results = []
for key in model_search_results.keys():
    row = [key, model_search_results[key]['best_params'], model_search_results[key]['test_MAPE']]
    results.append(row)

df_results = pd.DataFrame(data=results, columns=['Model', 'Best Parameters', 'Test MAPE'])
df_results['Test MAPE'] = df_results['Test MAPE'].apply(lambda x: format(float(x), ".4f"))
df_results.sort_values('Test MAPE')
# Out:
# Empty DataFrame
# Columns: [Model, Best Parameters, Test MAPE]
# Index: []
